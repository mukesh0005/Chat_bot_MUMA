# %%
import pandas as pd
from pprint import pprint 
import json
import openai
import re
import os
import pinecone
import time


import nltk
from nltk.tokenize import word_tokenize


import langchain
from langchain.llms import OpenAI
from langchain.chat_models import ChatOpenAI
from langchain.vectorstores import Pinecone
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.schema import SystemMessage, HumanMessage, AIMessage


from dotenv import load_dotenv, find_dotenv
# Out:
# C:\Users\Uday Ganti\anaconda3\lib\site-packages\pinecone\index.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# C:\Users\Uday Ganti\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
load_dotenv(find_dotenv())
# Out:
# True

# %%
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")
PINECONE_INDEX_NAME = os.getenv("PINECONE_INDEX_NAME")
PINECONE_ENVIRONMENT = os.getenv("PINECONE_ENVIRONMENT")

# %%
file_path = "./Data/jira-conversations2.json"

with open(file_path, "r", encoding='utf-8') as f:
    data = json.load(f)

# %%
json_data = data

# %%
def clean_text(text):
    text = ' '.join(text.split())  # Remove extra whitespaces and newlines
    
    # Remove different kinds of unwanted patterns from text
    # Remove unwanted patterns
    text = re.sub(r'~+\+~+', '', text)  # Remove ~+~+
    text = re.sub(r'\+\~', '', text)  # Remove +~
    text = re.sub(r'----', '', text)  # Remove ----
    text = re.sub(r'\+\+', '', text)    # Remove ++
    

    text = re.sub(r'~accountid:[a-zA-Z0-9]+', '', text)
    text = re.sub(r'\{"type".*?\}\]', '', text)
    text = re.sub(r'\{adf\}.*?\{adf\}', '', text)  # Remove "{adf} ... {adf}" and content within
    text = re.sub(r'\[~~email~~-?\d+~~\]', '', text)  # Remove `[~~email~~-numbers~~]`
    text = re.sub(r'http[s]?://\S+', '', text)  # Remove URLs
    text = re.sub(r'<\[\[~~email~~-?\d+~~\]\]', '', text)  # Remove `<[[~~email~~-numbers~~]]>`
    text = re.sub(r'\|mailto:\[~~email~~-?\d+~~\]', '', text)  # Remove email tags
    text = re.sub(r'—-—-—-—', '', text)  # Remove "—-—-—-—"
    text = re.sub(r'\w{3}, \d{1,2} \w{3} \d{4}, \d{1,2}:\d{2} [apmAPM]{2}', '', text)  # Remove timestamps
    text = re.sub(r'\|\s+\|\s+You don\'t often get email from', '', text)  # Remove headers
    text = re.sub(r'\[Powered by Service Management.*?\]', '', text)  # Remove "[Powered by...]"
    text = re.sub(r'\[View request.*?&reserved=0\]', '', text)  # Remove "[View request...]"
    text = re.sub(r'\*\*\*Please reply above this line\*\*\*', '', text)  # Remove reply line
    text = re.sub(r'\|', '', text)  # Remove "|"
    text = re.sub(r'_', '', text)  # Remove "_"
    text = re.sub(r'\[mailto:\]', '', text)  # Remove "[mailto:]"
    text = re.sub(r'\[|\]', '', text)  # Remove "[" and "]"
    text = re.sub(r'<|>', '', text)  # Remove "<" and ">"
    text = re.sub(r'\*', '', text)  # Remove "*"
    text = re.sub(r'!jira[-a-zA-Z0-9 ()]+!', '', text)  # Remove Jira text
    
    return text

# Clean text in conversations
for conv in json_data:
    for key, value in conv.items():
        if isinstance(value, str):
            try:
                conv[key] = clean_text(value)
            except Exception as e:
                print(f"Error cleaning text in '{key}': {e}")
        else:
            print(f"Skipped cleaning text for key '{key}' as it's not a string.")

# %%
texts = [', '.join(f"'{k}': '{v}'" for k, v in item.items()) for item in json_data]

# %%
texts
# Out:
# ["'question000001': 'Hii This is gadipally UID-U6331114. In process of submitting DS160. I need to send address and phone number of point of contact(school official).So can you please send address and phone number of IRIS BRITO(School official to contact uon arrival).Can i also know the first and last name of IRIS BRITO. Thank you.', 'response000002': 'Thank you for reaching out. You are able to add at . Best,'",
#  "'question000001': 'Hello, I am with ID - U20309912. I have not received any mail regarding academic integrity course . Can you please send the link for academic integrity course and details regarding it?! Thanks in advance.', 'response000002': 'Hello, provide me with your USF email.', 'question000003': 'Hello, USF mail Id is Thanks in advance', 'response000004': 'Canvas invite has been sent via email.', 'question000005': 'Hello , I didn’t get any canvas invite to my mail. Can you please send it again?! Thanks in advance', 'response000006': 'Invite has been sent again.'",
#  "'question000001': 'Sir/Madam, Greetings of the day!! Thank you for your email and I would like to change my program from MS Computer Science to MS Information Technology program. Please let me know the procedure to change my program and further process my application. Waiting for your quick and positive response. Thanks and , {quote} Hello! Thank you for applying to our MS BAIS program. At this time, it has been decided that we are not moving forward with your application. Our program does fill up quickly and in order for us to best serve each student, we have reached capacity. We understand this is not your first option, but we strongly encourage you to reapply for spring 2024 or fall 2024. We are happy to answer any questions, as you are making this decision whether or not to move forward. We do hope you choose to be considered for a future start. Thank you for considering USF! MS BAIS Academic Advisor School of Information Systems and Management {quote}', 'response000002': 'If you are interested in applying for another program, you will have to start another application. Best,'",
#  "'question000001': 'Hi Could you kindly let me know my pre requisites. My UID is U05191359. Regards,', 'response000002': 'Hi, Thank you for your request to do a prerequisite check. The system that I use to check your records is down and I therefore cannot do the check at this stage. I will try again later. Sorry. With kind regards, , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida', 'question000003': 'Hi, The system that I use to check your records is still down. This is very frustrating for me, as I am sure it is for you. If you send me your unofficial transcript and the resume that you uploaded when you created your application, I can use those to do the prerequisite check. With apologies – Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida', 'response000004': 'Hi I'm attaching my resume and unofficial transcript, kindly let me know my pre requisites. Thanks, From: Sent: Tuesday, April 18, 2023 9:13:08 PM To: Subject: MUMAJIRA-1562 Pre Requisite Check commented: Hi, The system that I use to check your records is still down. This is very frustrating for me, as I am sure it is for you. If you send me your unofficial transcript and the resume that you uploaded when you created your application, I can use those to do the prerequisite check. With apologies – Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida mailto: View request · Turn off this request's notifications Powered by Service Management Sent on April 18, 2023 11:43:07 AM EDT (19.32 MB) (195 kB)', 'question000005': 'Hi, Thank you for sending me the documents. I have reviewed them, and you have the following prerequisites to complet Economics Financial Accounting You can find a link with courses you can take to satisfy the prerequisites at It is of course possible that I overlooked something in either your resume or your transcript that would allow us to waive more prerequisites. If so, please let me know within 30 days of receipt of this email. Please do so by responding to this message, and do not create a message from scratch. With kind regards, , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Hi Could you kindly let me know my pre requisites. My UID is U43202780. Regards,', 'response000002': 'Hi, Thank you for your request to do a prerequisite check. The system that I use to check your records is down and I therefore cannot do the check at this stage. I will try again later. Sorry. With kind regards, , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida', 'question000003': 'Hi, Thank you for your request to do a prerequisite check. I have reviewed your transcripts and resume from your application, and you have the following prerequisites to complete: Economics Financial Accounting You can find a link with courses you can take to satisfy the prerequisites at It is of course possible that I overlooked something in either your resume or your transcript that would allow us to waive more prerequisites. If so, please let me know within 30 days of receipt of this email. Please do so by responding to this message, and do not create a message from scratch. With kind regards, , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Sir/Madam, Greetings of the day!!! This is , Thanks for giving the admission and i-20 for BAIS (Fall 2023) . I am writing this mail to inquire about the prerequisite courses that I need to take up before the start of my First class in Aug 2023 ? Can you please verify my profile and do the needful. Below are the details for your reference: - USF ID: U58683362 Undergraduate Major : Computer Science Job Experience : Yes (Software Engineer) I look forward to hearing from you. ,', 'response000002': 'Hi, Thank you for your request to do a prerequisite check. The system that I use to check your records is down and I therefore cannot do the check at this stage. I will try again later. Sorry. With kind regards, , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida', 'question000003': 'Hi, Thank you for your request to do a prerequisite check. The system is back up. However, according to my records you have not yet registered for orientation, and I cannot do the prerequisite check until you do so. So, please register for orientation and send me an email once you have done so. I can then do the prerequisite check. Thanks. , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida', 'response000004': 'Hi Team, I've successfully registered for the orientation. Can you please check now about my prerequisites.! Regards, .', 'question000005': 'Hi, Thanks for registering for orientation. Unfortunately, the system that we use to check your records is down. Sorry. I will try again later and get back to you. With kind regards , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida', 'response000006': 'Hi Can you please process my request as soon as possible. Regards, .', 'question000007': 'Hi, As I said, the system that we use to check your records is down. Sorry. Of course, had you done as we asked you do and registered for orientation before asking for a prerequisite check, we would not be in this situation. Anyway, IT is working on this, and I will try again later and get back to you. With kind regards , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida', 'response000008': 'Hi, The system that I used to look at your records has (finally) come back up. I have reviewed your transcripts and resume from your application, and you have the following prerequisites to complete: Economics Financial Accounting You can find a link with courses you can take to satisfy the prerequisites at It is of course possible that I overlooked something in either your resume or your transcript that would allow us to waive more prerequisites. If so, please let me know within 30 days of receipt of this email. Please do so by responding to this message, and do not create a message from scratch. With kind regards, , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida', 'question000009': 'Hi , Thank you for letting me know about my prerequisites. I got a small request from my side i.e is it ok if i complete Financial Accounting too from coursera itself as it would be easier for me and possibly save some cost. Hope you respond to this in a positive way and as soon as possible. Regards, .', 'response000010': 'Hi, The courses on the list are the only ones the faculty have approved. Sorry. With kind regards, , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  '\'question000001\': \'Hi I\'m delighted to have been admitted to such a prestigious school and program. But due to some unavoidable circumstances, I\'m considering deferral of my start date to next year/next intake. Can you please let me know the deferral policy and procedure? On Neyoo, wrote: {quote} Hi I\'m delighted to have been admitted to such a prestigious school and program. But due to some unavoidable circumstances, I\'m considering deferral of the program to next year/next intake. Can you please let me know the deferral policy and procedure? On MSBAIS Communications, wrote: Hi, Now that you have been admitted to the MS BAIS program, there are a number of additional steps we would like you to take. The file with the steps is attached. It is possible that you already received this file, in which case I apologize for unnecessarily filling your inbox With kind regards, , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida {quote}\', \'response000002\': \'Thank you for letting us know. Would you like to defer to spring 2024 or fall 2024. I can do this on your behalf. Best,\', \'question000003\': \'Hi Thank you for your response. Yes, that would be great. Please defer to Fall\'2024. Pranav Surve\', \'response000004\': \'Hi Requesting your response to my deferral request. I intend to defer to Fall\'24 as stated in my earlier email. Kindly confirm on the same. Regards Surve\', \'question000005\': \'Learn why this is important Hi Requesting your response to my deferral request. I intend to defer to Fall\'24 as stated in my earlier email. Kindly confirm on the same. Surve On Neyoo, wrote: {quote} Hi Thank you for your response. Yes, that would be great. Please defer to Fall\'2024. Surve On Saleh, wrote: commented: Thank you for letting us know. Would you like to defer to spring 2024 or fall 2024. I can do this on your behalf. Best, View request · Turn off this request\'s notifications Powered by Service Management Sent on April 12, 2023 4:04:35 PM EDT {quote}\', \'response000006\': \'Hi Gentle reminder! Can you please confirm if my deferral has been approved? Regards Surve\', \'question000007\': \'Learn why this is important Hi Gentle reminder! Can you please confirm if my deferral has been approved? Surve On , wrote: {quote} Hi Requesting your response to my deferral request. I intend to defer to Fall\'24 as stated in my earlier email. Kindly confirm on the same. Surve On , wrote: Hi Thank you for your response. Yes, that would be great. Please defer to Fall\'2024. Surve On Saleh, wrote: commented: Thank you for letting us know. Would you like to defer to spring 2024 or fall 2024. I can do this on your behalf. Best, View request · Turn off this request\'s notifications Powered by Service Management Sent on April 12, 2023 4:04:35 PM EDT {quote}\', \'response000008\': \'Respected Dean, I hope this email finds you in good health. I am reaching out to you with a polite request for assistance regarding my deferral approval. I have been in communication with the admissions team, regarding my deferral request to Fall 2024. Despite my previous emails and a gentle reminder (in trail), I have not received any confirmation or acknowledgment of my deferral. Considering the importance of this matter for my academic plans, I would be sincerely grateful if you could kindly expedite the review and approval process for my deferral request. Your intervention in resolving this issue would provide me with the clarity I need to proceed with my future plans confidently. Thank you for your understanding and attention to this matter. I eagerly await your response. Warm regards, Surve\', \'question000009\': \'Learn why this is important Respected Dean, I hope this email finds you in good health. I am reaching out to you with a polite request for assistance regarding my deferral approval. I have been in communication with the admissions team, regarding my deferral request to Fall 2024. Despite my previous  ...
#  "'question000001': 'Hi, I have not received my admission letter both soft and hard copy yet. Please send both so that I can process my financial aid. I received a link to my offer letter which redirected me to a jira account to which I had no access to. Kindly send me a PDF asap. Also, a hard copy to my address. U number- U78055250', 'response000002': 'HiI haven't recieved my e letter yet. Please respond as soon as possible', 'question000003': 'Please find the official letter attached. Thanks,', 'response000004': 'This link does not work, again. Please find a solution asap. !Screenshot (645).pngthumbnail!'",
#  "'question000001': 'Hi Team My usf email is - I am with USF ID: Term of Entry: 2023 Graduate Degree: Master of Science Graduate Major: Business Analytics and Information Systems I have received the admit for BAIS program -2023, and I require the official admit letter (electronic version) for the purpose of securing education loan to fund my masters. And also if I can get I-20 estimate for 2023-2024 as on website the pdf available is of 2022-2023. Please help me get it as soon as possible. to hear from you. Thanks, Chaudhary', 'response000002': 'I haven't received it yet. Any updates on this? Please let me know. Thanks & Regards Sanchit.', 'question000003': 'Please find the official letter attached. Thanks,', 'response000004': 'Hi , I can't open the attached pdf.It's (link) is just not opening up, I am getting an error message which I attached as screenshot. Can you please send it as attachment, I urgently need it to complete my loan application. Thanks and regards, Sanchit !!', 'question000005': 'Did you request a Jira account? You will need to create one, in order to view documents. Best,'",
#  "'question000001': 'Morning, Query - I have been waitlisted for the course Warehousing CRN 50118 on Mar 28. On 10th April morning, I checked the waitlist position as 6, and on Apr 11th the Waitlist position was 7. I observed that the waitlist position has changed from 6 to 7. So to confirm that there is a change I took a screenshot of the same. But surprisingly today (Apr 11) in the evening the Waitlist position - was changed from 7 to 8. Please find the screenshots of waitlist positions 7 and 8 below. I am really worried that I won't get a seat for this course. I am interested in taking warehousing course because my goal is to land a job in Engineering roles and I would like to know much more about how the data is collected and stored in data warehouses before they were processed and loaded into Databases. I am eagerly waiting for this course to be registered for summer 2023 since the same course was not offered in Fall 2023, also I am planning to graduate in Fall 2023 so I would like to take 2 courses in the summer. Right now for summer 2023, I have registered for Network, Systems, and Security CRN 52334, and Science Programming CRN 50184. I am okay to be dropped from CRN 50184 if I am registered for CRN 50118. I would really appreciate it if you can help address my query about the increase in the waitlist position and help me in registering for the course Warehousing CRN 50118. Thanks, , ', 'response000002': '!7.jpegthumbnail! !8.jpegthumbnail!', 'question000003': 'Hi, I am not sure why you dropped in the waitlist. I do not control it. As far as getting the Data Warehousing course is concerned, we are planning to offer the course in the Fall as well. Please keep an eye out for an announcement on this on the MS BAIS Current Students Canvas course. Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  '\'question000001\': \'Hi Professor, I am  Yenreddy, pursuing masters in BAIS at USF.I was not able to register for any classes for fall 2023 and I am unable to select desired courses both for summer and Fall 2023.I am interested to enroll in Data ware housing course. But there is only one class available for summer 2023 and it is full. The course is not available in Fall. Could you please increase the seats for the course or open course for fall 2023. Also same with course Solutions Architecture, which is having only one class for Fall 2023. Thanks,  U23954654\', \'response000002\': \'Hi, Thank you for your request to enroll you for courses in the Fall. Dr  and I have looked at the situation and we will be adding a number of face-to-face courses to the schedule. We are looking at the restrictions on the various courses that you want to register for. Once we have greater clarity on all this, I will leave a message on the MS BAIS Current Students Canvas course, and you should be able to find additional courses to register for. We therefore will not, at this point, manually register you for any courses. In the meantime, please be patient. Best – Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida\', \'question000003\': \'Han, Did you send this to the student or just to me?   Assistant Director MBA Programs and Graduate Certificate Director Graduate Studies Office Muma College of Business University of South  (813) 974-4153/(813) 974-4518 (fax) Pronouns: She/Her/Hers !image001.pngthumbnail! Program links:  MBA Programs   Master\'s Programs   Application Process  "Due to Florida’s broad open records law, email to or from university employees is public record, available to the public and the media upon request.” From:   Sent: Wednesday, April 12, 2023 1:27 PM To:   Subject: MUMAJIRA-1553 Please help me getting DataWare housing and Solutions Architechture Courses\'',
#  "'question000001': 'Professor, I look forward to registering in these courses ISM 6577 (Decision Processes for Business Continuity & Recovery) with CRN 82280 or 82292, and ISM 6328 (Information Security & Management) with CRN 80347. Please enroll me to these courses as I want to graduate this December. Apologies for the inconvenience. Regards, ', 'response000002': 'Hi, Thank you for your request to enroll you for courses in the Fall. Dr  and I have looked at the situation and we will be adding a number of face-to-face courses to the schedule. We are looking at the restrictions on the various courses that you want to register for. Once we have greater clarity on all this, I will leave a message on the MS BAIS Current Students Canvas course, and you should be able to find additional courses to register for. We therefore will not, at this point, manually register you for any courses. In the meantime, please be patient. Best – Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Hi Team, Greetings of the day! Hope my mail finds you well. My self is P. VIJAY TEJ (U1966-9900) currently Pursuing masters in business analytics & Information systems. As I’m Interested to register for Project Management & 82280 - DP &BCDR courses for the upcoming Fall - 2023 semester. Since I haven’t received any courses during course registration & In - fact after registration those subjects are also been dropped and I’m not having any option. Kindly request your help for register into both courses. Thanks & regards, P. VIJAY TEJ.', 'response000002': 'Hi, Thank you for your request to enroll you for courses in the Fall. Dr  and I have looked at the situation and we will be adding a number of face-to-face courses to the schedule. We are looking at the restrictions on the various courses that you want to register for. Once we have greater clarity on all this, I will leave a message on the MS BAIS Current Students Canvas course, and you should be able to find additional courses to register for. We therefore will not, at this point, manually register you for any courses. In the meantime, please be patient. Best – Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Professor, I was only able to register for two courses, two other courses which I have registered are dropped and few have thrown errors while adding them back, now I require three more credits to register for fall semester. Please register me for any of these Project Management courses (CRN 80113, 80334, 82133), if possible. It would be of great help. Attaching my Unumber and email for reference U-number:  Mail id:  Best regards, ', 'response000002': 'Hi, Thank you for your request to enroll you for courses in the Fall. Dr  and I have looked at the situation and we will be adding a number of face-to-face courses to the schedule. We are looking at the restrictions on the various courses that you want to register for. Once we have greater clarity on all this, I will leave a message on the MS BAIS Current Students Canvas course, and you should be able to find additional courses to register for. We therefore will not, at this point, manually register you for any courses. In the meantime, please be patient. Best – Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Hello, I am  with UID U04880400 trying to register for Enterprise Information Systems Management with CRN No. 80275, which is the only core subject left for me to complete and I am unable to register because of the permit required restriction. Could you please help me to register to the course by giving the permit. Thank you in advance, .', 'response000002': 'Hi, You are not eligible for this course, as you would have known if you had used USF Staff Schedule Search as recommended on the MS BAIS Current Students web site. Your failure to use the information available to you leads to more and unnecessary work for us. Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': '{quote} Dear Admissions Committee:{quote} {quote} I am writing in response to your offer of admission to the MS BAIS Program. I appreciate your interest in me, but I regret to inform you that I will not be accepting your offer of admission. Thank you for your time and consideration.{quote} {quote} Sincerely,{quote} {quote} Kim{quote} 2023년 2월 24일 (금) 오전 5:50,  님이 작성: {quote} Hello, Congratulations We have recommended that you be admitted to the MS BAIS program for Fall 2023. You will receive an official acceptance once the Graduate School processes this request. At that time, you will be able to log into your application with the updated status. Keep in mind, it can take up to 15 business days in order to officially process this admit. We will not be able to provide an electronic version of your letter until this is completed. You will receive an email from the Graduate School, once your acceptance has been updated. Please include your U number, when you reach out for an electronic letter. We do not require a formal confirmation, but rather, ask you to register for orientation when the next email is received. As a new student, you will need to complete a few more steps before getting started: . We also encourage you to check out the New Graduate Student page at:  You will need to set up your  multifactor authentication , before you can log into your USF accounts. Save the date, our orientation will be August 17th. We will send you more information about arrival week soon. International Students: you will receive more information from Immigration Services in regard to I20 next steps. If you would like to set up office hours with them, access this link:  You are not able to access your  iStart account until you have been admitted by Graduate School. Please don't hesitate to reach out with any questions, as you continue to move forward. We can schedule a time to meet during virtual office hours Wednesday and Friday between 9:30am-11:30am EST. You can also join our 'Information Session each Thursday from 9:30am-10:00am EST. Congrats again and we look forward to connecting with you soon! With kind regards,  MS BAIS Academic Advisor School of Information Systems and Management Muma College of Business !image.pngthumbnail! {quote}', 'response000002': '!image.pngthumbnail!', 'question000003': 'Thank you for letting me know. I’ve cancelled your application for fall 2024. Best of luck, '",
#  "'question000001': 'Professor , Currently, I am enrolled in the following subjects. # Big for Business # Science Programming # System Analysis and Design # Information Systems And During Semester 1 I took the following Subject # Mining # Analytical Methods for Business # database Management Systems I am looking forward to taking the following elective subjects for Fall 2023 as they align well with my goals. I am registered for DIS but unable to register for these subjects. Kindly help with the registration of the following subjects. # Project Management # Business continuity and Disaster recovery Regards, ', 'response000002': 'Hi, Thank you for your request to enroll you for courses in the Fall. Dr  and I have looked at the situation and we will be adding a number of face-to-face courses to the schedule. We are looking at the restrictions on the various courses that you want to register for. Once we have greater clarity on all this, I will leave a message on the MS BAIS Current Students Canvas course, and you should be able to find additional courses to register for. We therefore will not, at this point, manually register you for any courses. In the meantime, please be patient. Best – Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Team, you are doing well! I am interested to register for Decision Processes for Business Continuity & Recovery - 82280 - ISM 6577 - 521 instead of Information Security & Management - ISM 6328 - 021. Requesting you to please make these necesary changes in my course registration for Fall 2023. ,  U28512729', 'response000002': 'Hi, Thank you for your request to enroll you for courses in the Fall. Dr  and I have looked at the situation and we will be adding a number of face-to-face courses to the schedule. We are looking at the restrictions on the various courses that you want to register for. Once we have greater clarity on all this, I will leave a message on the MS BAIS Current Students Canvas course, and you should be able to find additional courses to register for. We therefore will not, at this point, manually register you for any courses. In the meantime, please be patient. Best – Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Professor, Day. I am  , current graduate student at Muma College of Business. The courses that I have registered for the fall of 2023 are listed below. !image.pngthumbnail! I am aspiring to the roles of a product manager or a data scientist and would like to pursue courses related to those. I could not get this course due to its unavailability at my time slot of registration. Hence, I have registered for the Tech Foundation of AI course to attain my student status of acquiring 9 credits. I request that you drop me from the CRN: 86662 (Tech Foundation of AI course) and enroll me in the CRN: 80334 (Project Management course). This would help me in enhancing my project management skills. My U Number is U80765768, and I am also requesting that you not drop me from the Big and Science Programming wait list, as I am hoping to finish my Masters as early as possible. I am grateful for your assistance and understanding in this matter. If you need any further information from me, please let me know. I am looking forward to your positive response. Thank you for your time and consideration. Thanks &    U80765768', 'response000002': '!image.pngthumbnail!', 'question000003': 'Hi, Thank you for your request to enroll you for courses in the Fall. Dr  and I have looked at the situation and we will be adding a number of face-to-face courses to the schedule. We are looking at the restrictions on the various courses that you want to register for. Once we have greater clarity on all this, I will leave a message on the MS BAIS Current Students Canvas course, and you should be able to find additional courses to register for. We therefore will not, at this point, manually register you for any courses. In the meantime, please be patient. Best – Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Greetings for the day , I am writing this mail regarding the courses for Fall 2023 semester. Can you Please kindly Add me CRN NO 80458 ISM 6328 for Information Security & Management, CRN NO 80334 for Project management ISM 6316 and CRN NO 80156 for Enterprise Information Systems Management. I have only one course web registered till date. Please add me these subjects for Fall 2023. Thanks in advance. Regards, , U33032085.', 'response000002': 'Hi, Thank you for your request to enroll you for courses in the Fall. Dr  and I have looked at the situation and we will be adding a number of face-to-face courses to the schedule. We are looking at the restrictions on the various courses that you want to register for. Once we have greater clarity on all this, I will leave a message on the MS BAIS Current Students Canvas course, and you should be able to find additional courses to register for. We therefore will not, at this point, manually register you for any courses. In the meantime, please be patient. Best – Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Hello all, I was web-registered only two courses in the fall 2023. I need one more course of project management i.e. ISM 80334. Can you please add me for the Fall 2023 web-registration. Right now, only 13 seats are available in the classroom. Could you please add the project management for me ASAP. Regards,  Reddy , U33464027.', 'response000002': 'Hi, Thank you for your request to enroll you for courses in the Fall. Dr  and I have looked at the situation and we will be adding a number of face-to-face courses to the schedule. We are looking at the restrictions on the various courses that you want to register for. Once we have greater clarity on all this, I will leave a message on the MS BAIS Current Students Canvas course, and you should be able to find additional courses to register for. We therefore will not, at this point, manually register you for any courses. In the meantime, please be patient. Best – Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Greetings for the day , I am writing this mail regarding the subjetcs for Fall 2023 semester. Can you Please kindly Add me CRN NO 80458 ISM 6328 for Information Security & Management and CRN NO 80334 for Project management ISM 6316, I have only one course web registered till date. Please add me these subjects which will make 9 credits for Fall 2023. Thanks in advance. , , U69871422.', 'response000002': 'Hi, Thank you for your request to enroll you for courses in the Fall. Dr  and I have looked at the situation and we will be adding a number of face-to-face courses to the schedule. We are looking at the restrictions on the various courses that you want to register for. Once we have greater clarity on all this, I will leave a message on the MS BAIS Current Students Canvas course, and you should be able to find additional courses to register for. We therefore will not, at this point, manually register you for any courses. In the meantime, please be patient. Best – Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Professor , I am having a doubt that we can take subject online in summer and go out USA(India) and complete the course ? Thanks, ', 'response000002': 'Hi, Did you not get the email from ISS? It explains the situation. Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Hello, you are doing well! Kindly refer the below list to update my preferred courses and please register me based on the course availability. CRN 80347 - ISM 6328 021 - Information Security and Management CRN 82280 - ISM 6577 521 - Decision Processes for Business Continuity & Recovery CRN 82292 - ISM 6577 300 - Decision Processes for Business Continuity & Recovery Thank you. Best Regards', 'response000002': 'Hi, Thank you for your request to enroll you for courses in the Fall. Dr  and I have looked at the situation and we will be adding a number of face-to-face courses to the schedule. We are looking at the restrictions on the various courses that you want to register for. Once we have greater clarity on all this, I will leave a message on the MS BAIS Current Students Canvas course, and you should be able to find additional courses to register for. We therefore will not, at this point, manually register you for any courses. In the meantime, please be patient. Best – Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Hello, you are doing well! Kindly refer the below list to update my preferred courses and please register me based on the course availability. CRN 80334 - ISM 6316 901 - Management CRN 80113 - ISM 6316 021 - Management CRN 80347 - ISM 6328 021 - Information Security and Management CRN 82280 - ISM 6577 521 - Decision Processes for Business Continuity & Recovery CRN 82292 - ISM 6577 300 - Decision Processes for Business Continuity & Recovery Thank you. Best Regards   From:   Date: Tuesday, April 11, 2023 at 2:06 PM To: MS BAIS  Subject: Fall 2023 Registration Good Afternoon, My name is  with U95670175. I got my class registration slot for Fall 2023 at 1:00 PM and I could not register to the courses that I would like to. I would like to register to the below mentioned courses. CRN 80334 - Management CRN 82280 - BCDR Kindly help me with the registrations. Thank you. Best Regards ', 'response000002': 'Hi, Thank you for your request to enroll you for courses in the Fall. Dr  and I have looked at the situation and we will be adding a number of face-to-face courses to the schedule. We are looking at the restrictions on the various courses that you want to register for. Once we have greater clarity on all this, I will leave a message on the MS BAIS Current Students Canvas course, and you should be able to find additional courses to register for. We therefore will not, at this point, manually register you for any courses. In the meantime, please be patient. Best – Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Hi , I have registered for the courses Information Security & management at the time of registration, but it has been dropped from that course. Currently I have only one active registration for the fall semester and my remaining credits for completion of my graduation was 9. Can you please register me for the information Security and management course which will be helpful for completing my degree by the Fall semester. Thanks, , U32900491.', 'response000002': 'Hi, Thank you for your request to enroll you for courses in the Fall. Dr  and I have looked at the situation and we will be adding a number of face-to-face courses to the schedule. We are looking at the restrictions on the various courses that you want to register for. Once we have greater clarity on all this, I will leave a message on the MS BAIS Current Students Canvas course, and you should be able to find additional courses to register for. We therefore will not, at this point, manually register you for any courses. In the meantime, please be patient. Best – Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Hello, I am , a graduate student in BAIS with a UID of U35263346. I am interested in pursuing the course Information Security & Management(CRN 80458), ISM6328, during the Fall semester. I kindly request your approval to enroll in this class as my interest lies in this course and I’m going to graduate in the Fall of 2023. Best regards, ', 'response000002': 'Hi, Thank you for your request to enroll you for courses in the Fall. Dr  and I have looked at the situation and we will be adding a number of face-to-face courses to the schedule. We are looking at the restrictions on the various courses that you want to register for. Once we have greater clarity on all this, I will leave a message on the MS BAIS Current Students Canvas course, and you should be able to find additional courses to register for. We therefore will not, at this point, manually register you for any courses. In the meantime, please be patient. Best – Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Hello, I am writing to request a clarification on the summer 2023 college fee for each subject. As I was reviewing the tuition fees for the upcoming semesters, I noticed that the cost for each subject during the Fall 2022 and Spring 2023 semesters is around $2700 USD. However, when I received the fee for each subject for the summer 2023 semester, it was listed as $3000 USD. I wanted to confirm if this is the correct fee for the summer 2023 semester or if there has been a mistake. If possible, could you please check and verify the fee for me? I would appreciate any information or assistance you can provide regarding this matter. Thank you for your attention and help. I look forward to hearing from you soon. PFA Best regards, Siva.', 'response000002': '(64 kB) (46 kB)', 'question000003': 'Hi , The summer cost includes both the tuition, which is still $2,300, and the fees. You also pay these fees in the Spring and the Fall, as you will see if you look at your bill for the Spring. As I understand it, fees are calculated on a per semester basis, not on a per credit hour basis as tuition is. I hope that this helps. Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Greetings, I am  and my U Number is U99286608. I was planning to take some courses for the Fall semester but was unable to register to those classes due to unavailability of seats during my registration slot. I had these subjects in mind for a very long time and would like to study them during the course of my master's degree. I respectfully request your kind consideration in facilitating my enrollment into these courses. Below are the subjects that I request you to enroll me in:  Information Security & Management (80355) or any Information Security & Management Course  Decision Processes for Business Continuity & Recovery(82282)  Decision Processes for Business Continuity & Recovery (82280)  Foundations of AI (86662) Awaiting a positive response. Thanks &  Surya Teja ', 'response000002': 'Hi, Thank you for your request to enroll you for courses in the Fall. Dr  and I have looked at the situation and we will be adding a number of face-to-face courses to the schedule. We are looking at the restrictions on the various courses that you want to register for. Once we have greater clarity on all this, I will leave a message on the MS BAIS Current Students Canvas course, and you should be able to find additional courses to register for. We therefore will not, at this point, manually register you for any courses. In the meantime, please be patient. Best – Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Professor, I am a graduate student (U17620025) for MS in BAIS, During the Fall 2023 course registration I didn't get my interested subjects. Please register me for the Decision Processes for Business Continuity & Recovery course (CRN: 82280). Please do the needful help. And also can you please change the grade mode to regular for CRN 80334? Thank you so much for your help. Regards, Yogesh U17620025', 'response000002': 'Hi, Thank you for your request to enroll you for courses in the Fall. Dr  and I have looked at the situation and we will be adding a number of face-to-face courses to the schedule. We are looking at the restrictions on the various courses that you want to register for. Once we have greater clarity on all this, I will leave a message on the MS BAIS Current Students Canvas course, and you should be able to find additional courses to register for. We therefore will not, at this point, manually register you for any courses. In the meantime, please be patient. Best – Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Greetings for the day! I would like to bring in your kind attention that I intend to graduate in Fall. I have registered for Management and Information Security and risk management. I fail to understand why my courses were dropped. I want to do Management and information security and risk management in summer. Kindly consider my situation and do the possible accordingly. Thanks & Best Regards  4025413898', 'response000002': 'Please list the CRN for both courses that you were dropped from.', 'question000003': ' Greetings for the day!    Kindly find the CRN details of the subjects that I was dropped from for Summer :  Management- 50180    Fundamentals of Management & Analysis - 50127 Kindly find the CRN details of the subjects that I was dropped from for Fall :  Information Security & Management -80355  Thanks & Best Regards  U 8850 4979 ', 'response000004': 'Hi, Thank you for your request to enroll you for courses in the Fall. Dr  and I have looked at the situation and we will be adding a number of face-to-face courses to the schedule. We are looking at the restrictions on the various courses that you want to register for. Once we have greater clarity on all this, I will leave a message on the MS BAIS Current Students Canvas course, and you should be able to find additional courses to register for. We therefore will not, at this point, manually register you for any courses. In the meantime, please be patient. Best – Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Sir/Mam, Greetings. I am planning to graduate in Fall 2023, and currently, I am trying to get registered for Decision Processes for Business Continuity & Recovery CRN 82280 and Information Security & Management CRN 80347 but I couldn't register even though it has no field of study restriction. I would be grateful if you register me for CRN 82280, CRN 80347. In addition, I am interested/prefer in below CRNs of the courses:  CRN 82280  CRN 80347  CRN 82176 Thanks, ,   From:   Sent: Tuesday, April 11, 2023 3:44 PM To:   Subject: Re: Fall 2023 Course Registration,  Hi, send this email to  This will allow us to deal with this more effectively. Include your U number and the CRNs of the courses you prefer. Han -- Reichgelt, PhD Graduate Coordinator, MS BAIS Professor of Information Systems School of Information Systems and Management Muma College of Business University of South St Petersburg campus (727) 873-4786  From:   Sent: Tuesday, April 11, 2023 3:33 PM To:  Subject: Fall 2023 Course Registration, U59107089 Professor, Greetings. I am planning to graduate in Fall 2023, and currently, I am trying to get enroll for Decision Processes for Business Continuity & Recovery CRN 82280, but I couldn't even though it has no field of study restriction. I would be grateful if you register me for CRN 82280. Thanks, , U59107089', 'response000002': 'Hi, Thank you for your request to enroll you for courses in the Fall. Dr  and I have looked at the situation and we will be adding a number of face-to-face courses to the schedule. We are looking at the restrictions on the various courses that you want to register for. Once we have greater clarity on all this, I will leave a message on the MS BAIS Current Students Canvas course, and you should be able to find additional courses to register for. We therefore will not, at this point, manually register you for any courses. In the meantime, please be patient. Best – Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Hello, I am , a graduate student in BAIS with a UID of U35263346. I am interested in pursuing the course Systems Analysis & Design (CRN 50237), ISM6124, during the summer semester. I kindly request your approval to enroll in this class. Best regards, ', 'response000002': 'Hi, You are not eligible for this course, as you would have known if you had used USF Staff Schedule Search as recommended on the MS BAIS Current Students web site. Your failure to use the information available to you leads to more and unnecessary work for us. Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  '\'question000001\': \'Evening, I\'m going to complete my master\'s in December 2023. So, I kindly request that you provide me with the subject "warehousing with So, I kindly request that you provide me with the subject "warehousing with CRN 50118" for the summer break. And for me, not even one subject is registered for the fall semester. Science Programming with CRN 80148 is on the waiting list . Please register me for these two subjects. Thanks  Thanks  Student BAIS (Business Analytics and Information Systems) School of information systems and Management USF Muma College of Business  P: 8137055979  Email:  \', \'response000002\': \'Please provide me with your U-Number.\', \'question000003\': \'Hello, U number is U34932870.  {adf}},},}},},},},},},},},{"}\', \'response000004\': \'50118 is currently closed for the summer.\'',
# ...
#  "'question000001': 'Hi Team, I am  Madupu(U01264561). I would like to do my Masters's program in Information Assurance Concentration to reach my desired career. So, I am trying to register for the course: Decision Processes for Business Continuity & Recovery from spring 2023 but no luck. I want to enhance my knowledge more on this subject. To meet the eligibility for Information Assurance Concentration till now I have completed the below courses with good scores ISM 6328 Information Security & Management ISM 6316 Project Management ISM 6124 Advanced Systems Analysis and  ISM 6218 Advanced Database Management ISM 6136 Data Mining ISM 6155 Enterprise Information Systems Management ISM 6225 Distributed Information Systems ISM 6208 Data Warehousing - Registered for Summer 23 So please consider my request and register me for Decision Processes for Business Continuity & Recovery either for Summer 2023 or Fall 2023. Please find below details: Fall: 82292 ISM 6577 300 Decision Processes for Business Continuity & Recovery 82280 ISM 6577 521 Decision Processes for Business Continuity & Recovery Summer: CRN 50182 Decision Processes for Business Continuity & Recovery. Kindly do the needful. Thanks & Regards,  Madupu', 'response000002': 'Hi, I made an announcement on the MS BAIS Current Students Canvas course, which clearly stated that we would not manually register students. Sorry. Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Hi Team, I am  (U92801433). I would like to do my Masters's program in Information Assurance Concentration to reach my desired career. So I am trying to register for the course: Decision Processes for Business Continuity & Recovery from spring 2023 but no luck. I have raised a request via the online page as well but no luck. I have hands-on experience in performing Recovery and Business Continuity Plans from my past work. I want to enhance my knowledge more on this subject. To meet the eligibility for Information Assurance Concentration till now I have completed the below courses with good scores ISM 6328 Information Security & Management ISM 6316 Project Management ISM 6124 Advanced Systems Analysis and  ISM 6218 Advanced Database Management ISM 6136 Data Mining ISM 6155 Enterprise Information Systems Management ISM 6225 Distributed Information Systems ISM 6208 Data Warehousing - Registered for Summer 23 So please consider my request and register me for Decision Processes for Business Continuity & Recovery either for Summer 2023 or Fall 2023. Please find below details: Fall: 82292 ISM 6577 300 Decision Processes for Business Continuity & Recovery 82280 ISM 6577 521 Decision Processes for Business Continuity & Recovery Summer: CRN 50182 Decision Processes for Business Continuity & Recovery. Kindly do the needful. Thanks & Regards, Arepalli', 'response000002': 'Hi, I made an announcement on the MS BAIS Current Students Canvas course, which clearly stated that we would not manually register students. Sorry. Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida', 'question000003': 'Hi , I tried from my end via and via online portal to raise request but no luck. Please help me for this time this course is very important for me. Kindly do the need full. Thanks & Regards,  ', 'response000004': 'Hi , I tried from my end via and via online portal to raise request but no luck. Please help me for this time this course is very important for me. Kindly do the need full. Thanks & Regards,   From:  Reichgelt  Sent: Monday, May 1, 2023 10:57 AM To:   Subject: MUMAJIRA-2000 Requesting for Registering to Decision Processes for Business Continuity & Recovery    Reichgelt commented: Hi, I made an announcement on the MS BAIS Current Students Canvas course, which clearly stated that we would not manually register students. Sorry.  , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida  mailto: View request · Turn off this request's notifications Powered by Service Management Sent on May 1, 2023 10:56:58 AM EDT', 'question000005': 'Hi, I made an announcement on the MS BAIS Current Students Canvas course, which clearly stated that we would not manually register students. Did you actually read the announcement Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Hi Please find the attached copy of my Visa with the mail. Unumber:  Warm regards,  !IMG5028.jpgthumbnail!', 'response000002': '!IMG5028.jpgthumbnail!', 'question000003': ' Can you record this, acknowledge that we received it and register her if she has met all the other requirements? Thanks', 'response000004': 'Good morning! We have received your VISA! Have you received a link to the Academic Integrity Course?', 'question000005': 'Hi No, I haven't received it yet. I have only got the links to the prerequisites. Best Regards, ', 'response000006': 'Good morning! An invite for the Academic Integrity Course has been sent to your USF Email.', 'question000007': 'Hello, I am unable to register you for courses due to a current immunization hold. Please use the link below to update your immunization information.  Best regards, ', 'response000008': 'Hi Thank you for your assistance. Is it that I have to submit my medical report to get back on my academic integrity course? , ', 'question000009': 'Hi, You should be able to get into the academic integrity course. Have you accepted the invite? With kind regards, , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida', 'response000010': 'Hi No, I did not. It says I’m blocked from that course. Actually i had an access to it for a day and now it says I’m blocked. Could you please help me out? Regards, ', 'question000011': 'Are you signing in with your USF email address?', 'response000012': 'Hi Yes, I am\\! Looks like my account has been put on hold because I haven’t submitted my medical form yet!', 'question000013': 'Hi, I am sorry I have misled you. That is indeed the case. With kind regards, , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida', 'response000014': 'Hi, Thank you for your help! I have given my tests and I request you to please send me a copy of medical history & immunisation form. I’ll fill the same and get it singed from a medical professional. Best Regards, ', 'question000015': ' I am not sure what she needs but if you do, can you please send her the form or the URL of the web site where she can get this.', 'response000016': 'Hello, I am unable to register you for courses due to a current immunization hold.  Best regards, ', 'question000017': 'Hi, Thank you for your response. Please find the Medical history & immunisation records attached to this email. Please do the further needful accordingly. Look forward to hearing from you. ,  !IMG5255.jpgthumbnail! !IMG5254.jpgthumbnail!', 'response000018': 'Thank you so much! Did you upload your documentation to health services?', 'question000019': 'Hi, No, I did not. Do I have to upload the same document that I have sent ? Please let me know where to upload it ! Warm regards, ', 'response000020': 'Good morning, You can upload the records using the link below.  Best regards, '",
#  "'question000001': 'Hi Mr., Name: USF ID number:  USF Email:  Fall 2023 admit - MS BAIS I got below prerequisites to complete  Database Design  Economics  Financial Accounting I completed my prerequisites and attached the certificates of completion to this email. Thanks and  Prabakarrao On Thu, 23 Mar 2023 at 20:38, P  wrote: {quote} Hi Mr., There is no file attached to this email for the courses to take to satisfy the prerequisites. send me the course file. Thanks and regards Prabakarrao On Tue, 28 Feb 2023 at 02:26,   wrote: Hi, find attached your admission letter. As requested, I did a prerequisite check. I have reviewed your transcript and resume from your application, and you have the following prerequisites to complete:  Database Design-- This has to be completed before you can take Database System  Economics  Financial Accounting  Statistics - This has to be completed before you can take Analytical Methods for Business I attach a file with courses you can take to satisfy the prerequisites. It is of course possible that I overlooked something in your application that would allow us to waive one or more of the prerequisites I have assigned to you. If this is indeed the case, please let me know within 30 days of receipt of this email. With kind regards   Graduate Coordinator,  Business Analytics and Information Systems (BAIS) Program Professor of Information Systems University of South Florida     !image.pngthumbnail!  From: P  Sent: Wednesday, February 22, 2023 12:29 PM To:   Subject: Requesting for prerequisite review and official letter of admission Hello, Name: USF ID number:  USF Email:  Fall 2023 admit - MS BAIS As my graduate admission status is seen as admitted , I am requesting you for an official electronic version of the admission letter. And also kindly do the prerequisite review and share with me the prerequisite course details which I should be completing. Thanks and  Prabakarrao {quote}', 'response000002': '!image.pngthumbnail! (299 kB) (302 kB) (303 kB)', 'question000003': 'Hi, Thank you for this. You have now met all prerequisites. I look forward to seeing you on campus in the Fall. With kind regards, , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Ok, thanks for letting me know.  From:   Sent: Wednesday, April 26, 2023 7:10:41 PM To:   Cc:   Subject: RE: About hold on my oasis portal  –– Since August, I’ve stepped away from my graduate advising / admissions role to focus on my teaching and Prof.  at , will be working with MS BAIS students. I’ll copy his team on this email. Regards,     Instructor  Business Analytics and Information Systems (BAIS) Program  University of South Florida   mailto:   !image001.jpgthumbnail! From:   Sent: Wednesday, April 26, 2023 3:01 AM To:   Subject: About hold on my oasis portal Hi , Im jayaprakash, i have seen hold on my oasis portal can i know what is the reason for that and what i have to do to remove that hold U number : U36639718 Thanks and regards,  makkena ', 'response000002': '!image001.jpgthumbnail!', 'question000003': 'Hi, We use this hold to make sure we register you for your courses in the first semester. Once you have sent us your visa and have met all the other requirements, we will register you and remove the hold. With kind regards, , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Greetings of the day, I am writing this mail to request a prerequisite review, I have registered for the orientation. U Number:  U24582269 Best regards, ', 'response000002': 'Hi, Thank you for your request to do a prerequisite check. I have reviewed your transcripts and resume from your application, and you have the following prerequisites to complete:  Economics  Statistics - This has to be completed before you can take Analytical Methods for Business You can find a link with courses you can take to satisfy the prerequisites at  It is of course possible that I overlooked something in either your resume or your transcript that would allow us to waive more prerequisites. If so, please let me know within 30 days of receipt of this email. Please do so by responding to this message, and do not create a message from scratch. With kind regards, , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida', 'question000003': 'Professor , Thank you for reviewing my profile. Since I applied to MS in BAIS program based on my bachelor's degree in Information Technology, I would like to kindly bring to your notice that I also have a Business Masters degree and I had already enrolled for and Statistics during the first semester of my MBA (Master of Business administration) program and I have completed these courses successfully. We were taught statistics under the course Business Analytics -1.  covered in this course were Probability, Population and Sample, Distribution of Data, The Measure of Central Tendency, Conditional Probability and P-Value, Variability, standard deviation and modality. Please find the attached proof of documents for your reference. I kindly request you to waive off prerequisite subjects that I am required to complete.  Best Regards,    mailto: /    mailto:   Transportation Specialist  Relay Operations Center (ROC)  Development Center !image.pngthumbnail! (0.0 kB)', 'response000004': 'Hi, Thanks for this. I apologize for overlooking this. I can indeed waive both prerequisites. However, the business analytics course does not appear to have covered linear regression. I would strongly recommend that you do some internet research on this to make sure you will be successful in the Analytical Methods for Business course. You have now met all prerequisites and I look forward to seeing you on campus in the Fall. With kind regards, , PhD Graduate Coordinator, MS BAIS College of Business, University of South Florida', 'question000005': 'Hi prof. , Thank you for the prerequisite waiver. As recommended, I will do some research on linear regression and I will come prepared before coming to college. Regards,  '",
#  "'question000001': 'Professor I am trying to register for project management for the fall semester I am getting field of restriction, can you please remove the hold for project management for the fall semester for the crn’s 80334 and 87839 Sent from =X7aP0pxhHXZThDrV%2FSVKxDaxrhaIzarw7c9v07VxZSE%3D&reserved=0 for Windows', 'response000002': 'Hi, I made an announcement on the MS BAIS Current Students Canvas course, which clearly stated that we would not manually register students. Sorry. Han , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  "'question000001': 'Greetings, This email confirms the following the Muma College of Business (MCOB) Graduate Course Permit Request Form was submitted on 4/30/2023 by More. More U47955969 None/Non-Degree-Seeking Cybersecurity Advanced Systems Analysis & Design ISM 6124 50321 Summer 2023  521 Tampa / Off-Campus Tampa Tampa Stacee Bender Internal Note 13,14,15'",
#  "'question000001': 'Hello team, you're doing well! This email is in regard to the prerequisite review to be done for my application. Please find below my details, Student name:  #U-ID:  Program: Business analytics and information systems Intake: Fall 2023 Subjects in undergrad: Probability and statistics, C programming, Object-oriented programming with Java, Managerial economics and financial analysis, and foundations of management. Please let me know if you need anything else from my end. Thank you! , ', 'response000002': 'Hi, Thank you for your request to do a prerequisite check. I have reviewed your transcripts and resume from your application, and you have the following prerequisites to complete:  Economics  Statistics - This has to be completed before you can take Analytical Methods for Business You can find a link with courses you can take to satisfy the prerequisites at  It is of course possible that I overlooked something in either your resume or your transcript that would allow us to waive more prerequisites. If so, please let me know within 30 days of receipt of this email. Please do so by responding to this message, and do not create a message from scratch. With kind regards, , PhD Professor and Graduate Coordinator, MS BAIS College of Business, University of South Florida'",
#  ...]

# %%
class Document:
    def __init__(self, page_content, metadata):
        self.page_content = page_content
        self.metadata = metadata

    def __repr__(self):
        return f"Document(page_content='{self.page_content}', metadata={self.metadata})"


# Define a simple text splitting function
def split_text(text, chunk_size=1000):
    chunks = []
    for i in range(0, len(text), chunk_size):
        chunk = text[i:i+chunk_size]
        chunks.append(chunk)
    return chunks    


# Instantiate RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)

# Assuming the 'texts' list from previous code
documents_list = [Document(page_content=text, metadata={'text': text}) for text in texts]

# %%
pinecone.init(
    api_key=os.getenv('PINECONE_API_KEY'),  
    environment=os.getenv('PINECONE_ENV')  
)

# %%
if PINECONE_INDEX_NAME not in pinecone.list_indexes():
    pinecone.create_index(
        PINECONE_INDEX_NAME,
        dimension=1536,
        metric='cosine'
    )
    # wait for index to finish initialization
    while not pinecone.describe_index(PINECONE_INDEX_NAME).status['ready']:
        time.sleep(1)

index = pinecone.Index(PINECONE_INDEX_NAME)

# %%
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.00024,
#  'namespaces': {'': {'vector_count': 24}},
#  'total_vector_count': 24}

# %%
# pinecone.delete_index("langchain-index")

# %%
# pinecone.create_index("langchain-index", dimension=1536)

# %%
index_name = "langchain-index"

# %%
embeddings = OpenAIEmbeddings(deployment="text-embedding-ada-002") #EXPENSIVE - - - USE CAREFULLY

# %%
print(f"Total number of Documents is: {len(documents_list)}")

for i in range(len(documents_list)):
    try:
        document = documents_list[i]
        print(f"Processing document {i + 1}")

        # Split the document content using the split_text function
        chunks = split_text(document.page_content)

        for chunk in chunks:
            chunk_document = Document(page_content=chunk, metadata={'text': chunk})
            search = Pinecone.from_documents([chunk_document], embeddings, index_name=index_name)

    except Exception as e:
        print(f"Error processing document {i + 1}: {e}")
# Out:
# Total number of Documents is: 4412
# Processing document 1
# Processing document 2
# Processing document 3
# Processing document 4
# Processing document 5
# Processing document 6
# Processing document 7
# Processing document 8
# Processing document 9
# Processing document 10
# Processing document 11
# Processing document 12
# Processing document 13
# Processing document 14
# Processing document 15
# Processing document 16
# Processing document 17
# Processing document 18
# Processing document 19
# Processing document 20
# Processing document 21
# Processing document 22
# Processing document 23
# Processing document 24
# Processing document 25
# Processing document 26
# Processing document 27
# Processing document 28
# Processing document 29
# Processing document 30
# Processing document 31
# Processing document 32
# Processing document 33
# Processing document 34
# Processing document 35
# Processing document 36
# Processing document 37
# Processing document 38
# Processing document 39
# Processing document 40
# Processing document 41
# Processing document 42
# Processing document 43
# Processing document 44
# Processing document 45
# Processing document 46
# Processing document 47
# Processing document 48
# Processing document 49
# Processing document 50
# Processing document 51
# Processing document 52
# Processing document 53
# Processing document 54
# Processing document 55
# Processing document 56
# Processing document 57
# Processing document 58
# Processing document 59
# Processing document 60
# Processing document 61
# Processing document 62
# Processing document 63
# Processing document 64
# Processing document 65
# Processing document 66
# Processing document 67
# Processing document 68
# Processing document 69
# Processing document 70
# Processing document 71
# Processing document 72
# Processing document 73
# Processing document 74
# Processing document 75
# Processing document 76
# Processing document 77
# Processing document 78
# Processing document 79
# Processing document 80
# Processing document 81
# Processing document 82
# Processing document 83
# Processing document 84
# Processing document 85
# Processing document 86
# Processing document 87
# Processing document 88
# Processing document 89
# Processing document 90
# Processing document 91
# Processing document 92
# Processing document 93
# Processing document 94
# Processing document 95
# Processing document 96
# Processing document 97
# Processing document 98
# Processing document 99
# Processing document 100
# Processing document 101
# Processing document 102
# Processing document 103
# Processing document 104
# Processing document 105
# Processing document 106
# Processing document 107
# Processing document 108
# Processing document 109
# Processing document 110
# Processing document 111
# Processing document 112
# Processing document 113
# Processing document 114
# Processing document 115
# Processing document 116
# Processing document 117
# Processing document 118
# Processing document 119
# Processing document 120
# Processing document 121
# Processing document 122
# Processing document 123
# Processing document 124
# Processing document 125
# Processing document 126
# Processing document 127
# Processing document 128
# Processing document 129
# Processing document 130
# Processing document 131
# Processing document 132
# Processing document 133
# Processing document 134
# Processing document 135
# Processing document 136
# Processing document 137
# Processing document 138
# Processing document 139
# Processing document 140
# Processing document 141
# Processing document 142
# Processing document 143
# Processing document 144
# Processing document 145
# Processing document 146
# Processing document 147
# Processing document 148
# Processing document 149
# Processing document 150
# Processing document 151
# Processing document 152
# Processing document 153
# Processing document 154
# Processing document 155
# Processing document 156
# Processing document 157
# Processing document 158
# Processing document 159
# Processing document 160
# Processing document 161
# Processing document 162
# Processing document 163
# Processing document 164
# Processing document 165
# Processing document 166
# Processing document 167
# Processing document 168
# Processing document 169
# Processing document 170
# Processing document 171
# Processing document 172
# Processing document 173
# Processing document 174
# Processing document 175
# Processing document 176
# Processing document 177
# Processing document 178
# Processing document 179
# Processing document 180
# Processing document 181
# Processing document 182
# Processing document 183
# Processing document 184
# Processing document 185
# Processing document 186
# Processing document 187
# Processing document 188
# Processing document 189
# Processing document 190
# Processing document 191
# Processing document 192
# Processing document 193
# Processing document 194
# Processing document 195
# Processing document 196
# Processing document 197
# Processing document 198
# Processing document 199
# Processing document 200
# Processing document 201
# Processing document 202
# Processing document 203
# Processing document 204
# Processing document 205
# Processing document 206
# Processing document 207
# Processing document 208
# Processing document 209
# Processing document 210
# Processing document 211
# Processing document 212
# Processing document 213
# Processing document 214
# Processing document 215
# Processing document 216
# Processing document 217
# Processing document 218
# Processing document 219
# Processing document 220
# Processing document 221
# Processing document 222
# Processing document 223
# Processing document 224
# Processing document 225
# Processing document 226
# Processing document 227
# Processing document 228
# Processing document 229
# Processing document 230
# Processing document 231
# Processing document 232
# Processing document 233
# Processing document 234
# Processing document 235
# Processing document 236
# Processing document 237
# Processing document 238
# Processing document 239
# Processing document 240
# Processing document 241
# Processing document 242
# Processing document 243
# Processing document 244
# Processing document 245
# Processing document 246
# Processing document 247
# Processing document 248
# Processing document 249
# Processing document 250
# Processing document 251
# Processing document 252
# Processing document 253
# Processing document 254
# Processing document 255
# Processing document 256
# Processing document 257
# Processing document 258
# Processing document 259
# Processing document 260
# Processing document 261
# Processing document 262
# Processing document 263
# Processing document 264
# Processing document 265
# Processing document 266
# Processing document 267
# Processing document 268
# Processing document 269
# Processing document 270
# Processing document 271
# Processing document 272
# Processing document 273
# Processing document 274
# Processing document 275
# Processing document 276
# Processing document 277
# Processing document 278
# Processing document 279
# Processing document 280
# Processing document 281
# Processing document 282
# Processing document 283
# Processing document 284
# Processing document 285
# Processing document 286
# Processing document 287
# Processing document 288
# Processing document 289
# Processing document 290
# Processing document 291
# Processing document 292
# Processing document 293
# Processing document 294
# Processing document 295
# Processing document 296
# Processing document 297
# Processing document 298
# Processing document 299
# Processing document 300
# Processing document 301
# Processing document 302
# Processing document 303
# Processing document 304
# Processing document 305
# Processing document 306
# Processing document 307
# Processing document 308
# Processing document 309
# Processing document 310
# Processing document 311
# Processing document 312
# Processing document 313
# Processing document 314
# Processing document 315
# Processing document 316
# Processing document 317
# Processing document 318
# Processing document 319
# Processing document 320
# Processing document 321
# Processing document 322
# Processing document 323
# Processing document 324
# Processing document 325
# Processing document 326
# Processing document 327
# Processing document 328
# Processing document 329
# Processing document 330
# Processing document 331
# Processing document 332
# Processing document 333
# Processing document 334
# Processing document 335
# Processing document 336
# Processing document 337
# Processing document 338
# Processing document 339
# Processing document 340
# Processing document 341
# Processing document 342
# Processing document 343
# Processing document 344
# Processing document 345
# Processing document 346
# Processing document 347
# Processing document 348
# Processing document 349
# Processing document 350
# Processing document 351
# Processing document 352
# Processing document 353
# Processing document 354
# Processing document 355
# Processing document 356
# Processing document 357
# Processing document 358
# Processing document 359
# Processing document 360
# Processing document 361
# Processing document 362
# Processing document 363
# Processing document 364
# Processing document 365
# Processing document 366
# Processing document 367
# Processing document 368
# Processing document 369
# Processing document 370
# Processing document 371
# Processing document 372
# Processing document 373
# Processing document 374
# Processing document 375
# Processing document 376
# Processing document 377
# Processing document 378
# Processing document 379
# Processing document 380
# Processing document 381
# Processing document 382
# Processing document 383
# Processing document 384
# Processing document 385
# Processing document 386
# Processing document 387
# Processing document 388
# Processing document 389
# Processing document 390
# Processing document 391
# Processing document 392
# Processing document 393
# Processing document 394
# Processing document 395
# Processing document 396
# Processing document 397
# Processing document 398
# Processing document 399
# Processing document 400
# Processing document 401
# Processing document 402
# Processing document 403
# Processing document 404
# Processing document 405
# Processing document 406
# Processing document 407
# Processing document 408
# Processing document 409
# Processing document 410
# Processing document 411
# Processing document 412
# Processing document 413
# Processing document 414
# Processing document 415
# Processing document 416
# Processing document 417
# Processing document 418
# Processing document 419
# Processing document 420
# Processing document 421
# Processing document 422
# Processing document 423
# Processing document 424
# Processing document 425
# Processing document 426
# Processing document 427
# Processing document 428
# Processing document 429
# Processing document 430
# Processing document 431
# Processing document 432
# Processing document 433
# Processing document 434
# Processing document 435
# Processing document 436
# Processing document 437
# Processing document 438
# Processing document 439
# Processing document 440
# Processing document 441
# Processing document 442
# Processing document 443
# Processing document 444
# Processing document 445
# Processing document 446
# Processing document 447
# Processing document 448
# Processing document 449
# Processing document 450
# Processing document 451
# Processing document 452
# Processing document 453
# Processing document 454
# Processing document 455
# Processing document 456
# Processing document 457
# Processing document 458
# Processing document 459
# Processing document 460
# Processing document 461
# Processing document 462
# Processing document 463
# Processing document 464
# Processing document 465
# Processing document 466
# Processing document 467
# Processing document 468
# Processing document 469
# Processing document 470
# Processing document 471
# Processing document 472
# Processing document 473
# Processing document 474
# Processing document 475
# Processing document 476
# Processing document 477
# Processing document 478
# Processing document 479
# Processing document 480
# Processing document 481
# Processing document 482
# Processing document 483
# Processing document 484
# Processing document 485
# Processing document 486
# Processing document 487
# Processing document 488
# Processing document 489
# Processing document 490
# Processing document 491
# Processing document 492
# Processing document 493
# Processing document 494
# Processing document 495
# Processing document 496
# Processing document 497
# Processing document 498
# Processing document 499
# Processing document 500
# Processing document 501
# Processing document 502
# Processing document 503
# Processing document 504
# Processing document 505
# Processing document 506
# Processing document 507
# Processing document 508
# Processing document 509
# Processing document 510
# Processing document 511
# Processing document 512
# Processing document 513
# Processing document 514
# Processing document 515
# Processing document 516
# Processing document 517
# Processing document 518
# Processing document 519
# Processing document 520
# Processing document 521
# Processing document 522
# Processing document 523
# Processing document 524
# Processing document 525
# Processing document 526
# Processing document 527
# Processing document 528
# Processing document 529
# Processing document 530
# Processing document 531
# Processing document 532
# Processing document 533
# Processing document 534
# Processing document 535
# Processing document 536
# Processing document 537
# Processing document 538
# Processing document 539
# Processing document 540
# Processing document 541
# Processing document 542
# Processing document 543
# Processing document 544
# Processing document 545
# Processing document 546
# Processing document 547
# Processing document 548
# Processing document 549
# Processing document 550
# Processing document 551
# Processing document 552
# Processing document 553
# Processing document 554
# Processing document 555
# Processing document 556
# Processing document 557
# Processing document 558
# Processing document 559
# Processing document 560
# Processing document 561
# Processing document 562
# Processing document 563
# Processing document 564
# Processing document 565
# Processing document 566
# Processing document 567
# Processing document 568
# Processing document 569
# Processing document 570
# Processing document 571
# Processing document 572
# Processing document 573
# Processing document 574
# Processing document 575
# Processing document 576
# Processing document 577
# Processing document 578
# Processing document 579
# Processing document 580
# Processing document 581
# Processing document 582
# Processing document 583
# Processing document 584
# Processing document 585
# Processing document 586
# Processing document 587
# Processing document 588
# Processing document 589
# Processing document 590
# Processing document 591
# Processing document 592
# Processing document 593
# Processing document 594
# Processing document 595
# Processing document 596
# Processing document 597
# Processing document 598
# Processing document 599
# Processing document 600
# Processing document 601
# Processing document 602
# Processing document 603
# Processing document 604
# Processing document 605
# Processing document 606
# Processing document 607
# Processing document 608
# Processing document 609
# Processing document 610
# Processing document 611
# Processing document 612
# Processing document 613
# Processing document 614
# Processing document 615
# Processing document 616
# Processing document 617
# Processing document 618
# Processing document 619
# Processing document 620
# Processing document 621
# Processing document 622
# Processing document 623
# Processing document 624
# Processing document 625
# Processing document 626
# Processing document 627
# Processing document 628
# Processing document 629
# Processing document 630
# Processing document 631
# Processing document 632
# Processing document 633
# Processing document 634
# Processing document 635
# Processing document 636
# Processing document 637
# Processing document 638
# Processing document 639
# Processing document 640
# Processing document 641
# Processing document 642
# Processing document 643
# Processing document 644
# Processing document 645
# Processing document 646
# Processing document 647
# Processing document 648
# Processing document 649
# Processing document 650
# Processing document 651
# Processing document 652
# Processing document 653
# Processing document 654
# Processing document 655
# Processing document 656
# Processing document 657
# Processing document 658
# Processing document 659
# Processing document 660
# Processing document 661
# Processing document 662
# Processing document 663
# Processing document 664
# Processing document 665
# Processing document 666
# Processing document 667
# Processing document 668
# Processing document 669
# Processing document 670
# Processing document 671
# Processing document 672
# Processing document 673
# Processing document 674
# Processing document 675
# Processing document 676
# Processing document 677
# Processing document 678
# Processing document 679
# Processing document 680
# Processing document 681
# Processing document 682
# Processing document 683
# Processing document 684
# Processing document 685
# Processing document 686
# Processing document 687
# Processing document 688
# Processing document 689
# Processing document 690
# Processing document 691
# Processing document 692
# Processing document 693
# Processing document 694
# Processing document 695
# Processing document 696
# Processing document 697
# Processing document 698
# Processing document 699
# Processing document 700
# Processing document 701
# Processing document 702
# Processing document 703
# Processing document 704
# Processing document 705
# Processing document 706
# Processing document 707
# Processing document 708
# Processing document 709
# Processing document 710
# Processing document 711
# Processing document 712
# Processing document 713
# Processing document 714
# Processing document 715
# Processing document 716
# Processing document 717
# Processing document 718
# Processing document 719
# Processing document 720
# Processing document 721
# Processing document 722
# Processing document 723
# Processing document 724
# Processing document 725
# Processing document 726
# Processing document 727
# Processing document 728
# Processing document 729
# Processing document 730
# Processing document 731
# Processing document 732
# Processing document 733
# Processing document 734
# Processing document 735
# Processing document 736
# Processing document 737
# Processing document 738
# Processing document 739
# Processing document 740
# Processing document 741
# Processing document 742
# Processing document 743
# Processing document 744
# Processing document 745
# Processing document 746
# Processing document 747
# Processing document 748
# Processing document 749
# Processing document 750
# Processing document 751
# Processing document 752
# Processing document 753
# Processing document 754
# Processing document 755
# Processing document 756
# Processing document 757
# Processing document 758
# Processing document 759
# Processing document 760
# Processing document 761
# Processing document 762
# Processing document 763
# Processing document 764
# Processing document 765
# Processing document 766
# Processing document 767
# Processing document 768
# Processing document 769
# Processing document 770
# Processing document 771
# Processing document 772
# Processing document 773
# Processing document 774
# Processing document 775
# Processing document 776
# Processing document 777
# Processing document 778
# Processing document 779
# Processing document 780
# Processing document 781
# Processing document 782
# Processing document 783
# Processing document 784
# Processing document 785
# Processing document 786
# Processing document 787
# Processing document 788
# Processing document 789
# Processing document 790
# Processing document 791
# Processing document 792
# Processing document 793
# Processing document 794
# Processing document 795
# Processing document 796
# Processing document 797
# Processing document 798
# Processing document 799
# Processing document 800
# Processing document 801
# Processing document 802
# Processing document 803
# Processing document 804
# Processing document 805
# Processing document 806
# Processing document 807
# Processing document 808
# Processing document 809
# Processing document 810
# Processing document 811
# Processing document 812
# Processing document 813
# Processing document 814
# Processing document 815
# Processing document 816
# Processing document 817
# Processing document 818
# Processing document 819
# Processing document 820
# Processing document 821
# Processing document 822
# Processing document 823
# Processing document 824
# Processing document 825
# Processing document 826
# Processing document 827
# Processing document 828
# Processing document 829
# Processing document 830
# Processing document 831
# Processing document 832
# Processing document 833
# Processing document 834
# Processing document 835
# Processing document 836
# Processing document 837
# Processing document 838
# Processing document 839
# Processing document 840
# Processing document 841
# Processing document 842
# Processing document 843
# Processing document 844
# Processing document 845
# Processing document 846
# Processing document 847
# Processing document 848
# Processing document 849
# Processing document 850
# Processing document 851
# Processing document 852
# Processing document 853
# Processing document 854
# Processing document 855
# Processing document 856
# Processing document 857
# Processing document 858
# Processing document 859
# Processing document 860
# Processing document 861
# Processing document 862
# Processing document 863
# Processing document 864
# Processing document 865
# Processing document 866
# Processing document 867
# Processing document 868
# Processing document 869
# Processing document 870
# Processing document 871
# Processing document 872
# Processing document 873
# Processing document 874
# Processing document 875
# Processing document 876
# Processing document 877
# Processing document 878
# Processing document 879
# Processing document 880
# Processing document 881
# Processing document 882
# Processing document 883
# Processing document 884
# Processing document 885
# Processing document 886
# Processing document 887
# Processing document 888
# Processing document 889
# Processing document 890
# Processing document 891
# Processing document 892
# Processing document 893
# Processing document 894
# Processing document 895
# Processing document 896
# Processing document 897
# Processing document 898
# Processing document 899
# Processing document 900
# Processing document 901
# Processing document 902
# Processing document 903
# Processing document 904
# Processing document 905
# Processing document 906
# Processing document 907
# Processing document 908
# Processing document 909
# Processing document 910
# Processing document 911
# Processing document 912
# Processing document 913
# Processing document 914
# Processing document 915
# Processing document 916
# Processing document 917
# Processing document 918
# Processing document 919
# Processing document 920
# Processing document 921
# Processing document 922
# Processing document 923
# Processing document 924
# Processing document 925
# Processing document 926
# Processing document 927
# Processing document 928
# Processing document 929
# Processing document 930
# Processing document 931
# Processing document 932
# Processing document 933
# Processing document 934
# Processing document 935
# Processing document 936
# Processing document 937
# Processing document 938
# Processing document 939
# Processing document 940
# Processing document 941
# Processing document 942
# Processing document 943
# Processing document 944
# Processing document 945
# Processing document 946
# Processing document 947
# Processing document 948
# Processing document 949
# Processing document 950
# Processing document 951
# Processing document 952
# Processing document 953
# Processing document 954
# Processing document 955
# Processing document 956
# Processing document 957
# Processing document 958
# Processing document 959
# Processing document 960
# Processing document 961
# Processing document 962
# Processing document 963
# Processing document 964
# Processing document 965
# Processing document 966
# Processing document 967
# Processing document 968
# Processing document 969
# Processing document 970
# Processing document 971
# Processing document 972
# Processing document 973
# Processing document 974
# Processing document 975
# Processing document 976
# Processing document 977
# Processing document 978
# Processing document 979
# Processing document 980
# Processing document 981
# Processing document 982
# Processing document 983
# Processing document 984
# Processing document 985
# Processing document 986
# Processing document 987
# Processing document 988
# Processing document 989
# Processing document 990
# Processing document 991
# Processing document 992
# Processing document 993
# Processing document 994
# Processing document 995
# Processing document 996
# Processing document 997
# Processing document 998
# Processing document 999
# Processing document 1000
# Processing document 1001
# Processing document 1002
# Processing document 1003
# Processing document 1004
# Processing document 1005
# Processing document 1006
# Processing document 1007
# Processing document 1008
# Processing document 1009
# Processing document 1010
# Processing document 1011
# Processing document 1012
# Processing document 1013
# Processing document 1014
# Processing document 1015
# Processing document 1016
# Processing document 1017
# Processing document 1018
# Processing document 1019
# Processing document 1020
# Processing document 1021
# Processing document 1022
# Processing document 1023
# Processing document 1024
# Processing document 1025
# Processing document 1026
# Processing document 1027
# Processing document 1028
# Processing document 1029
# Processing document 1030
# Processing document 1031
# Processing document 1032
# Processing document 1033
# Processing document 1034
# Processing document 1035
# Processing document 1036
# Processing document 1037
# Processing document 1038
# Processing document 1039
# Processing document 1040
# Processing document 1041
# Processing document 1042
# Processing document 1043
# Processing document 1044
# Processing document 1045
# Processing document 1046
# Processing document 1047
# Processing document 1048
# Processing document 1049
# Processing document 1050
# Processing document 1051
# Processing document 1052
# Processing document 1053
# Processing document 1054
# Processing document 1055
# Processing document 1056
# Processing document 1057
# Processing document 1058
# Processing document 1059
# Processing document 1060
# Processing document 1061
# Processing document 1062
# Processing document 1063
# Processing document 1064
# Processing document 1065
# Processing document 1066
# Processing document 1067
# Processing document 1068
# Processing document 1069
# Processing document 1070
# Processing document 1071
# Processing document 1072
# Processing document 1073
# Processing document 1074
# Processing document 1075
# Processing document 1076
# Processing document 1077
# Processing document 1078
# Processing document 1079
# Processing document 1080
# Processing document 1081
# Processing document 1082
# Processing document 1083
# Processing document 1084
# Processing document 1085
# Processing document 1086
# Processing document 1087
# Processing document 1088
# Processing document 1089
# Processing document 1090
# Processing document 1091
# Processing document 1092
# Processing document 1093
# Processing document 1094
# Processing document 1095
# Processing document 1096
# Processing document 1097
# Processing document 1098
# Processing document 1099
# Processing document 1100
# Processing document 1101
# Processing document 1102
# Processing document 1103
# Processing document 1104
# Processing document 1105
# Processing document 1106
# Processing document 1107
# Processing document 1108
# Processing document 1109
# Processing document 1110
# Processing document 1111
# Processing document 1112
# Processing document 1113
# Processing document 1114
# Processing document 1115
# Processing document 1116
# Processing document 1117
# Processing document 1118
# Processing document 1119
# Processing document 1120
# Processing document 1121
# Processing document 1122
# Processing document 1123
# Processing document 1124
# Processing document 1125
# Processing document 1126
# Processing document 1127
# Processing document 1128
# Processing document 1129
# Processing document 1130
# Processing document 1131
# Processing document 1132
# Processing document 1133
# Processing document 1134
# Processing document 1135
# Processing document 1136
# Processing document 1137
# Processing document 1138
# Processing document 1139
# Processing document 1140
# Processing document 1141
# Processing document 1142
# Processing document 1143
# Processing document 1144
# Processing document 1145
# Processing document 1146
# Processing document 1147
# Processing document 1148
# Processing document 1149
# Processing document 1150
# Processing document 1151
# Processing document 1152
# Processing document 1153
# Processing document 1154
# Processing document 1155
# Processing document 1156
# Processing document 1157
# Processing document 1158
# Processing document 1159
# Processing document 1160
# Processing document 1161
# Processing document 1162
# Processing document 1163
# Processing document 1164
# Processing document 1165
# Processing document 1166
# Processing document 1167
# Processing document 1168
# Processing document 1169
# Processing document 1170
# Processing document 1171
# Processing document 1172
# Processing document 1173
# Processing document 1174
# Processing document 1175
# Processing document 1176
# Processing document 1177
# Processing document 1178
# Processing document 1179
# Processing document 1180
# Processing document 1181
# Processing document 1182
# Processing document 1183
# Processing document 1184
# Processing document 1185
# Processing document 1186
# Processing document 1187
# Processing document 1188
# Processing document 1189
# Processing document 1190
# Processing document 1191
# Processing document 1192
# Processing document 1193
# Processing document 1194
# Processing document 1195
# Processing document 1196
# Processing document 1197
# Processing document 1198
# Processing document 1199
# Processing document 1200
# Processing document 1201
# Processing document 1202
# Processing document 1203
# Processing document 1204
# Processing document 1205
# Processing document 1206
# Processing document 1207
# Processing document 1208
# Processing document 1209
# Processing document 1210
# Processing document 1211
# Processing document 1212
# Processing document 1213
# Processing document 1214
# Processing document 1215
# Processing document 1216
# Processing document 1217
# Processing document 1218
# Processing document 1219
# Processing document 1220
# Processing document 1221
# Processing document 1222
# Processing document 1223
# Processing document 1224
# Processing document 1225
# Processing document 1226
# Processing document 1227
# Processing document 1228
# Processing document 1229
# Processing document 1230
# Processing document 1231
# Processing document 1232
# Processing document 1233
# Processing document 1234
# Processing document 1235
# Processing document 1236
# Processing document 1237
# Processing document 1238
# Processing document 1239
# Processing document 1240
# Processing document 1241
# Processing document 1242
# Processing document 1243
# Processing document 1244
# Processing document 1245
# Processing document 1246
# Processing document 1247
# Processing document 1248
# Processing document 1249
# Processing document 1250
# Processing document 1251
# Processing document 1252
# Processing document 1253
# Processing document 1254
# Processing document 1255
# Processing document 1256
# Processing document 1257
# Processing document 1258
# Processing document 1259
# Processing document 1260
# Processing document 1261
# Processing document 1262
# Processing document 1263
# Processing document 1264
# Processing document 1265
# Processing document 1266
# Processing document 1267
# Processing document 1268
# Processing document 1269
# Processing document 1270
# Processing document 1271
# Processing document 1272
# Processing document 1273
# Processing document 1274
# Processing document 1275
# Processing document 1276
# Processing document 1277
# Processing document 1278
# Processing document 1279
# Processing document 1280
# Processing document 1281
# Processing document 1282
# Processing document 1283
# Processing document 1284
# Processing document 1285
# Processing document 1286
# Processing document 1287
# Processing document 1288
# Processing document 1289
# Processing document 1290
# Processing document 1291
# Processing document 1292
# Processing document 1293
# Processing document 1294
# Processing document 1295
# Processing document 1296
# Processing document 1297
# Processing document 1298
# Processing document 1299
# Processing document 1300
# Processing document 1301
# Processing document 1302
# Processing document 1303
# Processing document 1304
# Processing document 1305
# Processing document 1306
# Processing document 1307
# Processing document 1308
# Processing document 1309
# Processing document 1310
# Processing document 1311
# Processing document 1312
# Processing document 1313
# Processing document 1314
# Processing document 1315
# Processing document 1316
# Processing document 1317
# Processing document 1318
# Processing document 1319
# Processing document 1320
# Processing document 1321
# Processing document 1322
# Processing document 1323
# Processing document 1324
# Processing document 1325
# Processing document 1326
# Processing document 1327
# Processing document 1328
# Processing document 1329
# Processing document 1330
# Processing document 1331
# Processing document 1332
# Processing document 1333
# Processing document 1334
# Processing document 1335
# Processing document 1336
# Processing document 1337
# Processing document 1338
# Processing document 1339
# Processing document 1340
# Processing document 1341
# Processing document 1342
# Processing document 1343
# Processing document 1344
# Processing document 1345
# Processing document 1346
# Processing document 1347
# Processing document 1348
# Processing document 1349
# Processing document 1350
# Processing document 1351
# Processing document 1352
# Processing document 1353
# Processing document 1354
# Processing document 1355
# Processing document 1356
# Processing document 1357
# Processing document 1358
# Processing document 1359
# Processing document 1360
# Processing document 1361
# Processing document 1362
# Processing document 1363
# Processing document 1364
# Processing document 1365
# Processing document 1366
# Processing document 1367
# Processing document 1368
# Processing document 1369
# Processing document 1370
# Processing document 1371
# Processing document 1372
# Processing document 1373
# Processing document 1374
# Processing document 1375
# Processing document 1376
# Processing document 1377
# Processing document 1378
# Processing document 1379
# Processing document 1380
# Processing document 1381
# Processing document 1382
# Processing document 1383
# Processing document 1384
# Processing document 1385
# Processing document 1386
# Processing document 1387
# Processing document 1388
# Processing document 1389
# Processing document 1390
# Processing document 1391
# Processing document 1392
# Processing document 1393
# Processing document 1394
# Processing document 1395
# Processing document 1396
# Processing document 1397
# Processing document 1398
# Processing document 1399
# Processing document 1400
# Processing document 1401
# Processing document 1402
# Processing document 1403
# Processing document 1404
# Processing document 1405
# Processing document 1406
# Processing document 1407
# Processing document 1408
# Processing document 1409
# Processing document 1410
# Processing document 1411
# Processing document 1412
# Processing document 1413
# Processing document 1414
# Processing document 1415
# Processing document 1416
# Processing document 1417
# Processing document 1418
# Processing document 1419
# Processing document 1420
# Processing document 1421
# Processing document 1422
# Processing document 1423
# Processing document 1424
# Processing document 1425
# Processing document 1426
# Processing document 1427
# Processing document 1428
# Processing document 1429
# Processing document 1430
# Processing document 1431
# Processing document 1432
# Processing document 1433
# Processing document 1434
# Processing document 1435
# Processing document 1436
# Processing document 1437
# Processing document 1438
# Processing document 1439
# Processing document 1440
# Processing document 1441
# Processing document 1442
# Processing document 1443
# Processing document 1444
# Processing document 1445
# Processing document 1446
# Processing document 1447
# Processing document 1448
# Processing document 1449
# Processing document 1450
# Processing document 1451
# Processing document 1452
# Processing document 1453
# Processing document 1454
# Processing document 1455
# Processing document 1456
# Processing document 1457
# Processing document 1458
# Processing document 1459
# Processing document 1460
# Processing document 1461
# Processing document 1462
# Processing document 1463
# Processing document 1464
# Processing document 1465
# Processing document 1466
# Processing document 1467
# Processing document 1468
# Processing document 1469
# Processing document 1470
# Processing document 1471
# Processing document 1472
# Processing document 1473
# Processing document 1474
# Processing document 1475
# Processing document 1476
# Processing document 1477
# Processing document 1478
# Processing document 1479
# Processing document 1480
# Processing document 1481
# Processing document 1482
# Processing document 1483
# Processing document 1484
# Processing document 1485
# Processing document 1486
# Processing document 1487
# Processing document 1488
# Processing document 1489
# Processing document 1490
# Processing document 1491
# Processing document 1492
# Processing document 1493
# Processing document 1494
# Processing document 1495
# Processing document 1496
# Processing document 1497
# Processing document 1498
# Processing document 1499
# Processing document 1500
# Processing document 1501
# Processing document 1502
# Processing document 1503
# Processing document 1504
# Processing document 1505
# Processing document 1506
# Processing document 1507
# Processing document 1508
# Processing document 1509
# Processing document 1510
# Processing document 1511
# Processing document 1512
# Processing document 1513
# Processing document 1514
# Processing document 1515
# Processing document 1516
# Processing document 1517
# Processing document 1518
# Processing document 1519
# Processing document 1520
# Processing document 1521
# Processing document 1522
# Processing document 1523
# Processing document 1524
# Processing document 1525
# Processing document 1526
# Processing document 1527
# Processing document 1528
# Processing document 1529
# Processing document 1530
# Processing document 1531
# Processing document 1532
# Processing document 1533
# Processing document 1534
# Processing document 1535
# Processing document 1536
# Processing document 1537
# Processing document 1538
# Processing document 1539
# Processing document 1540
# Processing document 1541
# Processing document 1542
# Processing document 1543
# Processing document 1544
# Processing document 1545
# Processing document 1546
# Processing document 1547
# Processing document 1548
# Processing document 1549
# Processing document 1550
# Processing document 1551
# Processing document 1552
# Processing document 1553
# Processing document 1554
# Processing document 1555
# Processing document 1556
# Processing document 1557
# Processing document 1558
# Processing document 1559
# Processing document 1560
# Processing document 1561
# Processing document 1562
# Processing document 1563
# Processing document 1564
# Processing document 1565
# Processing document 1566
# Processing document 1567
# Processing document 1568
# Processing document 1569
# Processing document 1570
# Processing document 1571
# Processing document 1572
# Processing document 1573
# Processing document 1574
# Processing document 1575
# Processing document 1576
# Processing document 1577
# Processing document 1578
# Processing document 1579
# Processing document 1580
# Processing document 1581
# Processing document 1582
# Processing document 1583
# Processing document 1584
# Processing document 1585
# Processing document 1586
# Processing document 1587
# Processing document 1588
# Processing document 1589
# Processing document 1590
# Processing document 1591
# Processing document 1592
# Processing document 1593
# Processing document 1594
# Processing document 1595
# Processing document 1596
# Processing document 1597
# Processing document 1598
# Processing document 1599
# Processing document 1600
# Processing document 1601
# Processing document 1602
# Processing document 1603
# Processing document 1604
# Processing document 1605
# Processing document 1606
# Processing document 1607
# Processing document 1608
# Processing document 1609
# Processing document 1610
# Processing document 1611
# Processing document 1612
# Processing document 1613
# Processing document 1614
# Processing document 1615
# Processing document 1616
# Processing document 1617
# Processing document 1618
# Processing document 1619
# Processing document 1620
# Processing document 1621
# Processing document 1622
# Processing document 1623
# Processing document 1624
# Processing document 1625
# Processing document 1626
# Processing document 1627
# Processing document 1628
# Processing document 1629
# Processing document 1630
# Processing document 1631
# Processing document 1632
# Processing document 1633
# Processing document 1634
# Processing document 1635
# Processing document 1636
# Processing document 1637
# Processing document 1638
# Processing document 1639
# Processing document 1640
# Processing document 1641
# Processing document 1642
# Processing document 1643
# Processing document 1644
# Processing document 1645
# Processing document 1646
# Processing document 1647
# Processing document 1648
# Processing document 1649
# Processing document 1650
# Processing document 1651
# Processing document 1652
# Processing document 1653
# Processing document 1654
# Processing document 1655
# Processing document 1656
# Processing document 1657
# Processing document 1658
# Processing document 1659
# Processing document 1660
# Processing document 1661
# Processing document 1662
# Processing document 1663
# Processing document 1664
# Processing document 1665
# Processing document 1666
# Processing document 1667
# Processing document 1668
# Processing document 1669
# Processing document 1670
# Processing document 1671
# Processing document 1672
# Processing document 1673
# Processing document 1674
# Processing document 1675
# Processing document 1676
# Processing document 1677
# Processing document 1678
# Processing document 1679
# Processing document 1680
# Processing document 1681
# Processing document 1682
# Processing document 1683
# Processing document 1684
# Processing document 1685
# Processing document 1686
# Processing document 1687
# Processing document 1688
# Processing document 1689
# Processing document 1690
# Processing document 1691
# Processing document 1692
# Processing document 1693
# Processing document 1694
# Processing document 1695
# Processing document 1696
# Processing document 1697
# Processing document 1698
# Processing document 1699
# Processing document 1700
# Processing document 1701
# Processing document 1702
# Processing document 1703
# Processing document 1704
# Processing document 1705
# Processing document 1706
# Processing document 1707
# Processing document 1708
# Processing document 1709
# Processing document 1710
# Processing document 1711
# Processing document 1712
# Processing document 1713
# Processing document 1714
# Processing document 1715
# Processing document 1716
# Processing document 1717
# Processing document 1718
# Processing document 1719
# Processing document 1720
# Processing document 1721
# Processing document 1722
# Processing document 1723
# Processing document 1724
# Processing document 1725
# Processing document 1726
# Processing document 1727
# Processing document 1728
# Processing document 1729
# Processing document 1730
# Processing document 1731
# Processing document 1732
# Processing document 1733
# Processing document 1734
# Processing document 1735
# Processing document 1736
# Processing document 1737
# Processing document 1738
# Processing document 1739
# Processing document 1740
# Processing document 1741
# Processing document 1742
# Processing document 1743
# Processing document 1744
# Processing document 1745
# Processing document 1746
# Processing document 1747
# Processing document 1748
# Processing document 1749
# Processing document 1750
# Processing document 1751
# Processing document 1752
# Processing document 1753
# Processing document 1754
# Processing document 1755
# Processing document 1756
# Processing document 1757
# Processing document 1758
# Processing document 1759
# Processing document 1760
# Processing document 1761
# Processing document 1762
# Processing document 1763
# Processing document 1764
# Processing document 1765
# Processing document 1766
# Processing document 1767
# Processing document 1768
# Processing document 1769
# Processing document 1770
# Processing document 1771
# Processing document 1772
# Processing document 1773
# Processing document 1774
# Processing document 1775
# Processing document 1776
# Processing document 1777
# Processing document 1778
# Processing document 1779
# Processing document 1780
# Processing document 1781
# Processing document 1782
# Processing document 1783
# Processing document 1784
# Processing document 1785
# Processing document 1786
# Processing document 1787
# Processing document 1788
# Processing document 1789
# Processing document 1790
# Processing document 1791
# Processing document 1792
# Processing document 1793
# Processing document 1794
# Processing document 1795
# Processing document 1796
# Processing document 1797
# Processing document 1798
# Processing document 1799
# Processing document 1800
# Processing document 1801
# Processing document 1802
# Processing document 1803
# Processing document 1804
# Processing document 1805
# Processing document 1806
# Processing document 1807
# Processing document 1808
# Processing document 1809
# Processing document 1810
# Processing document 1811
# Processing document 1812
# Processing document 1813
# Processing document 1814
# Processing document 1815
# Processing document 1816
# Processing document 1817
# Processing document 1818
# Processing document 1819
# Processing document 1820
# Processing document 1821
# Processing document 1822
# Processing document 1823
# Processing document 1824
# Processing document 1825
# Processing document 1826
# Processing document 1827
# Processing document 1828
# Processing document 1829
# Processing document 1830
# Processing document 1831
# Processing document 1832
# Processing document 1833
# Processing document 1834
# Processing document 1835
# Processing document 1836
# Processing document 1837
# Processing document 1838
# Processing document 1839
# Processing document 1840
# Processing document 1841
# Processing document 1842
# Processing document 1843
# Processing document 1844
# Processing document 1845
# Processing document 1846
# Processing document 1847
# Processing document 1848
# Processing document 1849
# Processing document 1850
# Processing document 1851
# Processing document 1852
# Processing document 1853
# Processing document 1854
# Processing document 1855
# Processing document 1856
# Processing document 1857
# Processing document 1858
# Processing document 1859
# Processing document 1860
# Processing document 1861
# Processing document 1862
# Processing document 1863
# Processing document 1864
# Processing document 1865
# Processing document 1866
# Processing document 1867
# Processing document 1868
# Processing document 1869
# Processing document 1870
# Processing document 1871
# Processing document 1872
# Processing document 1873
# Processing document 1874
# Processing document 1875
# Processing document 1876
# Processing document 1877
# Processing document 1878
# Processing document 1879
# Processing document 1880
# Processing document 1881
# Processing document 1882
# Processing document 1883
# Processing document 1884
# Processing document 1885
# Processing document 1886
# Processing document 1887
# Processing document 1888
# Processing document 1889
# Processing document 1890
# Processing document 1891
# Processing document 1892
# Processing document 1893
# Processing document 1894
# Processing document 1895
# Processing document 1896
# Processing document 1897
# Processing document 1898
# Processing document 1899
# Processing document 1900
# Processing document 1901
# Processing document 1902
# Processing document 1903
# Processing document 1904
# Processing document 1905
# Processing document 1906
# Processing document 1907
# Processing document 1908
# Processing document 1909
# Processing document 1910
# Processing document 1911
# Processing document 1912
# Processing document 1913
# Processing document 1914
# Processing document 1915
# Processing document 1916
# Processing document 1917
# Processing document 1918
# Processing document 1919
# Processing document 1920
# Processing document 1921
# Processing document 1922
# Processing document 1923
# Processing document 1924
# Processing document 1925
# Processing document 1926
# Processing document 1927
# Processing document 1928
# Processing document 1929
# Processing document 1930
# Processing document 1931
# Processing document 1932
# Processing document 1933
# Processing document 1934
# Processing document 1935
# Processing document 1936
# Processing document 1937
# Processing document 1938
# Processing document 1939
# Processing document 1940
# Processing document 1941
# Processing document 1942
# Processing document 1943
# Processing document 1944
# Processing document 1945
# Processing document 1946
# Processing document 1947
# Processing document 1948
# Processing document 1949
# Processing document 1950
# Processing document 1951
# Processing document 1952
# Processing document 1953
# Processing document 1954
# Processing document 1955
# Processing document 1956
# Processing document 1957
# Processing document 1958
# Processing document 1959
# Processing document 1960
# Processing document 1961
# Processing document 1962
# ...
# Processing document 3773
# Processing document 3774
# Processing document 3775
# Processing document 3776
# Processing document 3777
# Processing document 3778
# Processing document 3779
# Processing document 3780
# Processing document 3781
# Processing document 3782
# Processing document 3783
# Processing document 3784
# Processing document 3785
# Processing document 3786
# Processing document 3787
# Processing document 3788
# Processing document 3789
# Processing document 3790
# Processing document 3791
# Processing document 3792
# Processing document 3793
# Processing document 3794
# Processing document 3795
# Processing document 3796
# Processing document 3797
# Processing document 3798
# Processing document 3799
# Processing document 3800
# Processing document 3801
# Processing document 3802
# Processing document 3803
# Processing document 3804
# Processing document 3805
# Processing document 3806
# Processing document 3807
# Processing document 3808
# Processing document 3809
# Processing document 3810
# Processing document 3811
# Processing document 3812
# Processing document 3813
# Processing document 3814
# Processing document 3815
# Processing document 3816
# Processing document 3817
# Processing document 3818
# Processing document 3819
# Processing document 3820
# Processing document 3821
# Processing document 3822
# Processing document 3823
# Processing document 3824
# Processing document 3825
# Processing document 3826
# Processing document 3827
# Processing document 3828
# Processing document 3829
# Processing document 3830
# Processing document 3831
# Processing document 3832
# Processing document 3833
# Processing document 3834
# Processing document 3835
# Processing document 3836
# Processing document 3837
# Processing document 3838
# Processing document 3839
# Processing document 3840
# Processing document 3841
# Processing document 3842
# Processing document 3843
# Processing document 3844
# Processing document 3845
# Processing document 3846
# Processing document 3847
# Processing document 3848
# Processing document 3849
# Processing document 3850
# Processing document 3851
# Processing document 3852
# Processing document 3853
# Processing document 3854
# Processing document 3855
# Processing document 3856
# Processing document 3857
# Processing document 3858
# Processing document 3859
# Processing document 3860
# Processing document 3861
# Processing document 3862
# Processing document 3863
# Processing document 3864
# Processing document 3865
# Processing document 3866
# Processing document 3867
# Processing document 3868
# Processing document 3869
# Processing document 3870
# Processing document 3871
# Processing document 3872
# Processing document 3873
# Processing document 3874
# Processing document 3875
# Processing document 3876
# Processing document 3877
# Processing document 3878
# Processing document 3879
# Processing document 3880
# Processing document 3881
# Processing document 3882
# Processing document 3883
# Processing document 3884
# Processing document 3885
# Processing document 3886
# Processing document 3887
# Processing document 3888
# Processing document 3889
# Processing document 3890
# Processing document 3891
# Processing document 3892
# Processing document 3893
# Processing document 3894
# Processing document 3895
# Processing document 3896
# Processing document 3897
# Processing document 3898
# Processing document 3899
# Processing document 3900
# Processing document 3901
# Processing document 3902
# Processing document 3903
# Processing document 3904
# Processing document 3905
# Processing document 3906
# Processing document 3907
# Processing document 3908
# Processing document 3909
# Processing document 3910
# Processing document 3911
# Processing document 3912
# Processing document 3913
# Processing document 3914
# Processing document 3915
# Processing document 3916
# Processing document 3917
# Processing document 3918
# Processing document 3919
# Processing document 3920
# Processing document 3921
# Processing document 3922
# Processing document 3923
# Processing document 3924
# Processing document 3925
# Processing document 3926
# Processing document 3927
# Processing document 3928
# Processing document 3929
# Processing document 3930
# Processing document 3931
# Processing document 3932
# Processing document 3933
# Processing document 3934
# Processing document 3935
# Processing document 3936
# Processing document 3937
# Processing document 3938
# Processing document 3939
# Processing document 3940
# Processing document 3941
# Processing document 3942
# Processing document 3943
# Processing document 3944
# Processing document 3945
# Processing document 3946
# Processing document 3947
# Processing document 3948
# Processing document 3949
# Processing document 3950
# Processing document 3951
# Processing document 3952
# Processing document 3953
# Processing document 3954
# Processing document 3955
# Processing document 3956
# Processing document 3957
# Processing document 3958
# Processing document 3959
# Processing document 3960
# Processing document 3961
# Processing document 3962
# Processing document 3963
# Processing document 3964
# Processing document 3965
# Processing document 3966
# Processing document 3967
# Processing document 3968
# Processing document 3969
# Processing document 3970
# Processing document 3971
# Processing document 3972
# Processing document 3973
# Processing document 3974
# Processing document 3975
# Processing document 3976
# Processing document 3977
# Processing document 3978
# Processing document 3979
# Processing document 3980
# Processing document 3981
# Processing document 3982
# Processing document 3983
# Processing document 3984
# Processing document 3985
# Processing document 3986
# Processing document 3987
# Processing document 3988
# Processing document 3989
# Processing document 3990
# Processing document 3991
# Processing document 3992
# Processing document 3993
# Processing document 3994
# Processing document 3995
# Processing document 3996
# Processing document 3997
# Processing document 3998
# Processing document 3999
# Processing document 4000
# Processing document 4001
# Processing document 4002
# Processing document 4003
# Processing document 4004
# Processing document 4005
# Processing document 4006
# Processing document 4007
# Processing document 4008
# Processing document 4009
# Processing document 4010
# Processing document 4011
# Processing document 4012
# Processing document 4013
# Processing document 4014
# Processing document 4015
# Processing document 4016
# Processing document 4017
# Processing document 4018
# Processing document 4019
# Processing document 4020
# Processing document 4021
# Processing document 4022
# Processing document 4023
# Processing document 4024
# Processing document 4025
# Processing document 4026
# Processing document 4027
# Processing document 4028
# Processing document 4029
# Processing document 4030
# Processing document 4031
# Processing document 4032
# Processing document 4033
# Processing document 4034
# Processing document 4035
# Processing document 4036
# Processing document 4037
# Processing document 4038
# Processing document 4039
# Processing document 4040
# Processing document 4041
# Processing document 4042
# Processing document 4043
# Processing document 4044
# Processing document 4045
# Processing document 4046
# Processing document 4047
# Processing document 4048
# Processing document 4049
# Processing document 4050
# Processing document 4051
# Processing document 4052
# Processing document 4053
# Processing document 4054
# Processing document 4055
# Processing document 4056
# Processing document 4057
# Processing document 4058
# Processing document 4059
# Processing document 4060
# Processing document 4061
# Processing document 4062
# Processing document 4063
# Processing document 4064
# Processing document 4065
# Processing document 4066
# Processing document 4067
# Processing document 4068
# Processing document 4069
# Processing document 4070
# Processing document 4071
# Processing document 4072
# Processing document 4073
# Processing document 4074
# Processing document 4075
# Processing document 4076
# Processing document 4077
# Processing document 4078
# Processing document 4079
# Processing document 4080
# Processing document 4081
# Processing document 4082
# Processing document 4083
# Processing document 4084
# Processing document 4085
# Processing document 4086
# Processing document 4087
# Processing document 4088
# Processing document 4089
# Processing document 4090
# Processing document 4091
# Processing document 4092
# Processing document 4093
# Processing document 4094
# Processing document 4095
# Processing document 4096
# Processing document 4097
# Processing document 4098
# Processing document 4099
# Processing document 4100
# Processing document 4101
# Processing document 4102
# Processing document 4103
# Processing document 4104
# Processing document 4105
# Processing document 4106
# Processing document 4107
# Processing document 4108
# Processing document 4109
# Processing document 4110
# Processing document 4111
# Processing document 4112
# Processing document 4113
# Processing document 4114
# Processing document 4115
# Processing document 4116
# Processing document 4117
# Processing document 4118
# Processing document 4119
# Processing document 4120
# Processing document 4121
# Processing document 4122
# Processing document 4123
# Processing document 4124
# Processing document 4125
# Processing document 4126
# Processing document 4127
# Processing document 4128
# Processing document 4129
# Processing document 4130
# Processing document 4131
# Processing document 4132
# Processing document 4133
# Processing document 4134
# Processing document 4135
# Processing document 4136
# Processing document 4137
# Processing document 4138
# Processing document 4139
# Processing document 4140
# Processing document 4141
# Processing document 4142
# Processing document 4143
# Processing document 4144
# Processing document 4145
# Processing document 4146
# Processing document 4147
# Processing document 4148
# Processing document 4149
# Processing document 4150
# Processing document 4151
# Processing document 4152
# Processing document 4153
# Processing document 4154
# Processing document 4155
# Processing document 4156
# Processing document 4157
# Processing document 4158
# Processing document 4159
# Processing document 4160
# Processing document 4161
# Processing document 4162
# Processing document 4163
# Processing document 4164
# Processing document 4165
# Processing document 4166
# Processing document 4167
# Processing document 4168
# Processing document 4169
# Processing document 4170
# Processing document 4171
# Processing document 4172
# Processing document 4173
# Processing document 4174
# Processing document 4175
# Processing document 4176
# Processing document 4177
# Processing document 4178
# Processing document 4179
# Processing document 4180
# Processing document 4181
# Processing document 4182
# Processing document 4183
# Processing document 4184
# Processing document 4185
# Processing document 4186
# Processing document 4187
# Processing document 4188
# Processing document 4189
# Processing document 4190
# Processing document 4191
# Processing document 4192
# Processing document 4193
# Processing document 4194
# Processing document 4195
# Processing document 4196
# Processing document 4197
# Processing document 4198
# Processing document 4199
# Processing document 4200
# Processing document 4201
# Processing document 4202
# Processing document 4203
# Processing document 4204
# Processing document 4205
# Processing document 4206
# Processing document 4207
# Processing document 4208
# Processing document 4209
# Processing document 4210
# Processing document 4211
# Processing document 4212
# Processing document 4213
# Processing document 4214
# Processing document 4215
# Processing document 4216
# Processing document 4217
# Processing document 4218
# Processing document 4219
# Processing document 4220
# Processing document 4221
# Processing document 4222
# Processing document 4223
# Processing document 4224
# Processing document 4225
# Processing document 4226
# Processing document 4227
# Processing document 4228
# Processing document 4229
# Processing document 4230
# Processing document 4231
# Processing document 4232
# Processing document 4233
# Processing document 4234
# Processing document 4235
# Processing document 4236
# Processing document 4237
# Processing document 4238
# Processing document 4239
# Processing document 4240
# Processing document 4241
# Processing document 4242
# Processing document 4243
# Processing document 4244
# Processing document 4245
# Processing document 4246
# Processing document 4247
# Processing document 4248
# Processing document 4249
# Processing document 4250
# Processing document 4251
# Processing document 4252
# Processing document 4253
# Processing document 4254
# Processing document 4255
# Processing document 4256
# Processing document 4257
# Processing document 4258
# Processing document 4259
# Processing document 4260
# Processing document 4261
# Processing document 4262
# Processing document 4263
# Processing document 4264
# Processing document 4265
# Processing document 4266
# Processing document 4267
# Processing document 4268
# Processing document 4269
# Processing document 4270
# Processing document 4271
# Processing document 4272
# Processing document 4273
# Processing document 4274
# Processing document 4275
# Processing document 4276
# Processing document 4277
# Processing document 4278
# Processing document 4279
# Processing document 4280
# Processing document 4281
# Processing document 4282
# Processing document 4283
# Processing document 4284
# Processing document 4285
# Processing document 4286
# Processing document 4287
# Processing document 4288
# Processing document 4289
# Processing document 4290
# Processing document 4291
# Processing document 4292
# Processing document 4293
# Processing document 4294
# Processing document 4295
# Processing document 4296
# Processing document 4297
# Processing document 4298
# Processing document 4299
# Processing document 4300
# Processing document 4301
# Processing document 4302
# Processing document 4303
# Processing document 4304
# Processing document 4305
# Processing document 4306
# Processing document 4307
# Processing document 4308
# Processing document 4309
# Processing document 4310
# Processing document 4311
# Processing document 4312
# Processing document 4313
# Processing document 4314
# Processing document 4315
# Processing document 4316
# Processing document 4317
# Processing document 4318
# Processing document 4319
# Processing document 4320
# Processing document 4321
# Processing document 4322
# Processing document 4323
# Processing document 4324
# Processing document 4325
# Processing document 4326
# Processing document 4327
# Processing document 4328
# Processing document 4329
# Processing document 4330
# Processing document 4331
# Processing document 4332
# Processing document 4333
# Processing document 4334
# Processing document 4335
# Processing document 4336
# Processing document 4337
# Processing document 4338
# Processing document 4339
# Processing document 4340
# Processing document 4341
# Processing document 4342
# Processing document 4343
# Processing document 4344
# Processing document 4345
# Processing document 4346
# Processing document 4347
# Processing document 4348
# Processing document 4349
# Processing document 4350
# Processing document 4351
# Processing document 4352
# Processing document 4353
# Processing document 4354
# Processing document 4355
# Processing document 4356
# Processing document 4357
# Processing document 4358
# Processing document 4359
# Processing document 4360
# Processing document 4361
# Processing document 4362
# Processing document 4363
# Processing document 4364
# Processing document 4365
# Processing document 4366
# Processing document 4367
# Processing document 4368
# Processing document 4369
# Processing document 4370
# Processing document 4371
# Processing document 4372
# Processing document 4373
# Processing document 4374
# Processing document 4375
# Processing document 4376
# Processing document 4377
# Processing document 4378
# Processing document 4379
# Processing document 4380
# Processing document 4381
# Processing document 4382
# Processing document 4383
# Processing document 4384
# Processing document 4385
# Processing document 4386
# Processing document 4387
# Processing document 4388
# Processing document 4389
# Processing document 4390
# Processing document 4391
# Processing document 4392
# Processing document 4393
# Processing document 4394
# Processing document 4395
# Processing document 4396
# Processing document 4397
# Processing document 4398
# Processing document 4399
# Processing document 4400
# Processing document 4401
# Processing document 4402
# Processing document 4403
# Processing document 4404
# Processing document 4405
# Processing document 4406
# Processing document 4407
# Processing document 4408
# Processing document 4409
# Processing document 4410
# Processing document 4411
# Processing document 4412

# %%
# Do a simple vector similarity search
query = "I am having a doubt"

result = search.similarity_search(query)
result
# Out:
# []

# %%
# text_field = "text"  # the metadata field that contains our text

# # Initialize the vector store object
# vectorstore = Pinecone(
#     index, embeddings.embed_query, text_field
# )
# Out:
# C:\Users\Uday Ganti\anaconda3\lib\site-packages\langchain\vectorstores\pinecone.py:59: UserWarning: Passing in `embedding` as a Callable is deprecated. Please pass in an Embeddings object instead.
#   warnings.warn(

# %%
# scrapped_pages_dir = "./Data/Scrapped Pages"

# %%
# # Traverse the directory and get all .txt files
# txt_files = [f for f in os.listdir(scrapped_pages_dir) if f.endswith('.txt')]

# %%
# # Read the contents of each file and store in a list
# documents_list = []
# for file in txt_files:
#     with open(os.path.join(scrapped_pages_dir, file), 'r', encoding='utf-8') as f:
#         content = f.read()
#         documents_list.append(Document(page_content=content, metadata={'text': content}))

# %%
# print(f"Total number of Documents is: {len(documents_list)}")

# for i in range(len(documents_list)):
#     try:
#         document = documents_list[i]
#         print(f"Processing document {i + 1}")

#         # Split the document into chunks
#         chunks = split_text(document.page_content)

#         for chunk in chunks:
#             chunk_document = Document(page_content=chunk, metadata={'text': chunk})
#             # Vectorize the chunk
#             search = Pinecone.from_documents([chunk_document], embeddings, index_name=index_name)

#     except Exception as e:
#         print(f"Error processing document {i + 1}: {e}")
# Out:
# Total number of Documents is: 374
# Processing document 1
# Processing document 2
# Processing document 3
# Processing document 4
# Processing document 5
# Processing document 6
# Processing document 7
# Processing document 8
# Processing document 9
# Processing document 10
# Processing document 11
# Processing document 12
# Processing document 13
# Processing document 14
# Processing document 15
# Processing document 16
# Processing document 17
# Processing document 18
# Processing document 19
# Processing document 20
# Processing document 21
# Processing document 22
# Processing document 23
# Processing document 24
# Processing document 25
# Processing document 26
# Processing document 27
# Processing document 28
# Processing document 29
# Processing document 30
# Processing document 31
# Processing document 32
# Processing document 33
# Processing document 34
# Processing document 35
# Processing document 36
# Processing document 37
# Processing document 38
# Processing document 39
# Processing document 40
# Processing document 41
# Processing document 42
# Processing document 43
# Processing document 44
# Processing document 45
# Processing document 46
# Processing document 47
# Processing document 48
# Processing document 49
# Processing document 50
# Processing document 51
# Processing document 52
# Processing document 53
# Processing document 54
# Processing document 55
# Processing document 56
# Processing document 57
# Processing document 58
# Processing document 59
# Processing document 60
# Processing document 61
# Processing document 62
# Processing document 63
# Processing document 64
# Processing document 65
# Processing document 66
# Processing document 67
# Processing document 68
# Processing document 69
# Processing document 70
# Processing document 71
# Processing document 72
# Processing document 73
# Processing document 74
# Processing document 75
# Processing document 76
# Processing document 77
# Processing document 78
# Processing document 79
# Processing document 80
# Processing document 81
# Processing document 82
# Processing document 83
# Processing document 84
# Processing document 85
# Processing document 86
# Processing document 87
# Processing document 88
# Processing document 89
# Processing document 90
# Processing document 91
# Processing document 92
# Processing document 93
# Processing document 94
# Processing document 95
# Processing document 96
# Processing document 97
# Processing document 98
# Processing document 99
# Processing document 100
# Processing document 101
# Processing document 102
# Processing document 103
# Processing document 104
# Processing document 105
# Processing document 106
# Processing document 107
# Processing document 108
# Processing document 109
# Processing document 110
# Processing document 111
# Processing document 112
# Processing document 113
# Processing document 114
# Processing document 115
# Processing document 116
# Processing document 117
# Processing document 118
# Processing document 119
# Processing document 120
# Processing document 121
# Processing document 122
# Processing document 123
# Processing document 124
# Processing document 125
# Processing document 126
# Processing document 127
# Processing document 128
# Processing document 129
# Processing document 130
# Processing document 131
# Processing document 132
# Processing document 133
# Processing document 134
# Processing document 135
# Processing document 136
# Processing document 137
# Processing document 138
# Processing document 139
# Processing document 140
# Processing document 141
# Processing document 142
# Processing document 143
# Processing document 144
# Processing document 145
# Processing document 146
# Processing document 147
# Processing document 148
# Processing document 149
# Processing document 150
# Processing document 151
# Processing document 152
# Processing document 153
# Processing document 154
# Processing document 155
# Processing document 156
# Processing document 157
# Processing document 158
# Processing document 159
# Processing document 160
# Processing document 161
# Processing document 162
# Processing document 163
# Processing document 164
# Processing document 165
# Processing document 166
# Processing document 167
# Processing document 168
# Processing document 169
# Processing document 170
# Processing document 171
# Processing document 172
# Processing document 173
# Processing document 174
# Processing document 175
# Processing document 176
# Processing document 177
# Processing document 178
# Processing document 179
# Processing document 180
# Processing document 181
# Processing document 182
# Processing document 183
# Processing document 184
# Processing document 185
# Processing document 186
# Processing document 187
# Processing document 188
# Processing document 189
# Processing document 190
# Processing document 191
# Processing document 192
# Processing document 193
# Processing document 194
# Processing document 195
# Processing document 196
# Processing document 197
# Processing document 198
# Processing document 199
# Processing document 200
# Processing document 201
# Processing document 202
# Processing document 203
# Processing document 204
# Processing document 205
# Processing document 206
# Processing document 207
# Processing document 208
# Processing document 209
# Processing document 210
# Processing document 211
# Processing document 212
# Processing document 213
# Processing document 214
# Processing document 215
# Processing document 216
# Processing document 217
# Processing document 218
# Processing document 219
# Processing document 220
# Processing document 221
# Processing document 222
# Processing document 223
# Processing document 224
# Processing document 225
# Processing document 226
# Processing document 227
# Processing document 228
# Processing document 229
# Processing document 230
# Processing document 231
# Processing document 232
# Processing document 233
# Processing document 234
# Processing document 235
# Processing document 236
# Processing document 237
# Processing document 238
# Processing document 239
# Processing document 240
# Processing document 241
# Processing document 242
# Processing document 243
# Processing document 244
# Processing document 245
# Processing document 246
# Processing document 247
# Processing document 248
# Processing document 249
# Processing document 250
# Processing document 251
# Processing document 252
# Processing document 253
# Processing document 254
# Processing document 255
# Processing document 256
# Processing document 257
# Processing document 258
# Processing document 259
# Processing document 260
# Processing document 261
# Processing document 262
# Processing document 263
# Processing document 264
# Processing document 265
# Processing document 266
# Processing document 267
# Processing document 268
# Processing document 269
# Processing document 270
# Processing document 271
# Processing document 272
# Processing document 273
# Processing document 274
# Processing document 275
# Processing document 276
# Processing document 277
# Processing document 278
# Processing document 279
# Processing document 280
# Processing document 281
# Processing document 282
# Processing document 283
# Processing document 284
# Processing document 285
# Processing document 286
# Processing document 287
# Processing document 288
# Processing document 289
# Processing document 290
# Processing document 291
# Processing document 292
# Processing document 293
# Processing document 294
# Processing document 295
# Processing document 296
# Processing document 297
# Processing document 298
# Processing document 299
# Processing document 300
# Processing document 301
# Processing document 302
# Processing document 303
# Processing document 304
# Processing document 305
# Processing document 306
# Processing document 307
# Processing document 308
# Processing document 309
# Processing document 310
# Processing document 311
# Processing document 312
# Processing document 313
# Processing document 314
# Processing document 315
# Processing document 316
# Processing document 317
# Processing document 318
# Processing document 319
# Processing document 320
# Processing document 321
# Processing document 322
# Processing document 323
# Processing document 324
# Processing document 325
# Processing document 326
# Processing document 327
# Processing document 328
# Processing document 329
# Processing document 330
# Processing document 331
# Processing document 332
# Processing document 333
# Processing document 334
# Processing document 335
# Processing document 336
# Processing document 337
# Processing document 338
# Processing document 339
# Processing document 340
# Processing document 341
# Processing document 342
# Processing document 343
# Processing document 344
# Processing document 345
# Processing document 346
# Processing document 347
# Processing document 348
# Processing document 349
# Processing document 350
# Processing document 351
# Processing document 352
# Processing document 353
# Processing document 354
# Processing document 355
# Processing document 356
# Processing document 357
# Processing document 358
# Processing document 359
# Processing document 360
# Processing document 361
# Processing document 362
# Processing document 363
# Processing document 364
# Processing document 365
# Processing document 366
# Processing document 367
# Processing document 368
# Processing document 369
# Processing document 370
# Processing document 371
# Processing document 372
# Processing document 373
# Processing document 374

# %%
# # Initialize the vector store object
# vectorstore = Pinecone(
#     index, embeddings.embed_query, text_field
# )

# query = "Michelle Jahn"
# vectorstore.similarity_search(query, k=3)
# Out:
# [Document(page_content="Michelle JahnResearch Administratormmjahn@usf.eduCampus:\xa0TampaRoom:\xa0BSN 3111Phone:\xa0813-974-1512Michelle Jahn is the Muma College of Business research administrator, a role in which\n               she will assist faculty in ferreting out opportunities for funded research, the preparation\n               and submission of competitive proposals and the management of awarded grants.She currently is enrolled in the MBA program with the Muma College of Business and\n               received a bachelor's degree in marketing from USF in 2005. She has been with USF\n               since 2007 and has served as a fiscal and business specialist, a research administrator\n               and administrative specialist with USF Research and Innovation."),
#  Document(page_content='ffice Unit Research Administrator:\nMichelle Jahn\nmmjahn@usf.edu\n813-974-1512\nTampa Campus\nBSN 3111\nStaff Spotlight: Michelle Jahn is a one-person team helping faculty reach their research aspirations\nBehind every team of business school researchers, there is a behind-the-scenes person who helps the team function. At the USF Muma College of Business, that person is Michelle Jahn.\n   '),
#  Document(page_content='ffice Unit Research Administrator:\nMichelle Jahn\nmmjahn@usf.edu\n813-974-1512\nTampa Campus\nBSN 3111\nStaff Spotlight: Michelle Jahn is a one-person team helping faculty reach their research aspirations\nBehind every team of business school researchers, there is a behind-the-scenes person who helps the team function. At the USF Muma College of Business, that person is Michelle Jahn.\n   ')]

# %%
# text_folder_path = "./Data/Syllabus 2023-selected/Text"

# txt_files = [f for f in os.listdir(text_folder_path) if f.endswith('.txt')]

# # Read the contents of each file and store in a list
# documents_list = []
# for file in txt_files:
#     with open(os.path.join(text_folder_path, file), 'r', encoding='utf-8') as f:
#         content = f.read()
#         documents_list.append(Document(page_content=content, metadata={'text': content}))

# %%
# print(f"Total number of Documents is: {len(documents_list)}")

# for i in range(len(documents_list)):
#     try:
#         document = documents_list[i]
#         print(f"Processing document {i + 1}")

#         # Split the document into chunks using the split_text function
#         chunks = split_text(document.page_content)

#         for chunk in chunks:
#             chunk_document = Document(page_content=chunk, metadata={'text': chunk})
#             # Vectorize the chunk using Pinecone
#             search = Pinecone.from_documents([chunk_document], embeddings, index_name=index_name)

#     except Exception as e:
#         print(f"Error processing document {i + 1}: {e}")
# Out:
# Total number of Documents is: 282
# Processing document 1
# Processing document 2
# Processing document 3
# Processing document 4
# Processing document 5
# Processing document 6
# Processing document 7
# Processing document 8
# Error processing document 8: (500)
# Reason: Internal Server Error
# HTTP response headers: HTTPHeaderDict({'content-type': 'application/json', 'Content-Length': '150', 'date': 'Sun, 22 Oct 2023 20:43:35 GMT', 'x-envoy-upstream-service-time': '34', 'server': 'envoy', 'Via': '1.1 google', 'Alt-Svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000'})
# HTTP response body: {"code":13,"message":"We were unable to process your request. If the problem persists, please contact us at https://support.pinecone.io","details":[]}
#
# Processing document 9
# Processing document 10
# Processing document 11
# Processing document 12
# Processing document 13
# Processing document 14
# Processing document 15
# Processing document 16
# Processing document 17
# Processing document 18
# Processing document 19
# Processing document 20
# Processing document 21
# Processing document 22
# Processing document 23
# Processing document 24
# Processing document 25
# Processing document 26
# Processing document 27
# Processing document 28
# Processing document 29
# Processing document 30
# Processing document 31
# Processing document 32
# Processing document 33
# Processing document 34
# Processing document 35
# Processing document 36
# Processing document 37
# Processing document 38
# Processing document 39
# Processing document 40
# Processing document 41
# Processing document 42
# Processing document 43
# Processing document 44
# Processing document 45
# Processing document 46
# Processing document 47
# Processing document 48
# Processing document 49
# Processing document 50
# Processing document 51
# Processing document 52
# Processing document 53
# Processing document 54
# Processing document 55
# Processing document 56
# Processing document 57
# Processing document 58
# Processing document 59
# Processing document 60
# Processing document 61
# Processing document 62
# Processing document 63
# Processing document 64
# Processing document 65
# Processing document 66
# Processing document 67
# Processing document 68
# Processing document 69
# Processing document 70
# Processing document 71
# Processing document 72
# Processing document 73
# Processing document 74
# Processing document 75
# Processing document 76
# Processing document 77
# Processing document 78
# Processing document 79
# Processing document 80
# Processing document 81
# Processing document 82
# Processing document 83
# Processing document 84
# Processing document 85
# Processing document 86
# Processing document 87
# Processing document 88
# Processing document 89
# Processing document 90
# Processing document 91
# Processing document 92
# Processing document 93
# Processing document 94
# Processing document 95
# Processing document 96
# Processing document 97
# Processing document 98
# Processing document 99
# Processing document 100
# Processing document 101
# Processing document 102
# Processing document 103
# Processing document 104
# Processing document 105
# Processing document 106
# Processing document 107
# Processing document 108
# Processing document 109
# Processing document 110
# Processing document 111
# Processing document 112
# Processing document 113
# Processing document 114
# Processing document 115
# Processing document 116
# Processing document 117
# Processing document 118
# Processing document 119
# Processing document 120
# Processing document 121
# Processing document 122
# Processing document 123
# Processing document 124
# Processing document 125
# Processing document 126
# Processing document 127
# Processing document 128
# Processing document 129
# Processing document 130
# Processing document 131
# Processing document 132
# Processing document 133
# Processing document 134
# Processing document 135
# Processing document 136
# Processing document 137
# Processing document 138
# Processing document 139
# Processing document 140
# Processing document 141
# Processing document 142
# Processing document 143
# Processing document 144
# Processing document 145
# Processing document 146
# Processing document 147
# Processing document 148
# Processing document 149
# Processing document 150
# Processing document 151
# Processing document 152
# Processing document 153
# Processing document 154
# Processing document 155
# Processing document 156
# Processing document 157
# Processing document 158
# Processing document 159
# Processing document 160
# Processing document 161
# Processing document 162
# Processing document 163
# Processing document 164
# Processing document 165
# Processing document 166
# Processing document 167
# Processing document 168
# Processing document 169
# Processing document 170
# Processing document 171
# Processing document 172
# Processing document 173
# Processing document 174
# Processing document 175
# Processing document 176
# Processing document 177
# Processing document 178
# Processing document 179
# Processing document 180
# Processing document 181
# Processing document 182
# Processing document 183
# Processing document 184
# Processing document 185
# Processing document 186
# Processing document 187
# Processing document 188
# Processing document 189
# Processing document 190
# Processing document 191
# Processing document 192
# Processing document 193
# Processing document 194
# Processing document 195
# Processing document 196
# Processing document 197
# Processing document 198
# Processing document 199
# Processing document 200
# Processing document 201
# Processing document 202
# Processing document 203
# Processing document 204
# Processing document 205
# Processing document 206
# Processing document 207
# Processing document 208
# Processing document 209
# Processing document 210
# Processing document 211
# Processing document 212
# Processing document 213
# Processing document 214
# Processing document 215
# Processing document 216
# Processing document 217
# Processing document 218
# Processing document 219
# Processing document 220
# Processing document 221
# Processing document 222
# Processing document 223
# Processing document 224
# Processing document 225
# Processing document 226
# Processing document 227
# Processing document 228
# Processing document 229
# Processing document 230
# Processing document 231
# Processing document 232
# Processing document 233
# Processing document 234
# Processing document 235
# Processing document 236
# Processing document 237
# Processing document 238
# Processing document 239
# Processing document 240
# Processing document 241
# Processing document 242
# Processing document 243
# Processing document 244
# Processing document 245
# Processing document 246
# Processing document 247
# Processing document 248
# Processing document 249
# Processing document 250
# Processing document 251
# Processing document 252
# Processing document 253
# Processing document 254
# Processing document 255
# Processing document 256
# Processing document 257
# Processing document 258
# Processing document 259
# Processing document 260
# Processing document 261
# Processing document 262
# Processing document 263
# Processing document 264
# Processing document 265
# Processing document 266
# Processing document 267
# Processing document 268
# Processing document 269
# Processing document 270
# Processing document 271
# Processing document 272
# Processing document 273
# Processing document 274
# Processing document 275
# Processing document 276
# Processing document 277
# Processing document 278
# Processing document 279
# Processing document 280
# Processing document 281
# Processing document 282

# %%
# vectorstore = Pinecone(
#     index, embeddings.embed_query, text_field
# )

# query = "USF Student Conduct Code"
# sample = vectorstore.similarity_search(query, k=3)
# sample

# %% [markdown]
# # Adding New

# %%
import pandas as pd
from pprint import pprint 
import json
import openai
import re
import os
import pinecone
import time


import nltk
from nltk.tokenize import word_tokenize


import langchain
from langchain.llms import OpenAI
from langchain.chat_models import ChatOpenAI
from langchain.vectorstores import Pinecone
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.schema import SystemMessage, HumanMessage, AIMessage


from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())
# Out:
# C:\Users\Uday Ganti\anaconda3\lib\site-packages\pinecone\index.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# C:\Users\Uday Ganti\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# True

# %%
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")
PINECONE_INDEX_NAME = os.getenv("PINECONE_INDEX_NAME")
PINECONE_ENVIRONMENT = os.getenv("PINECONE_ENVIRONMENT")

# %%
pinecone.init(
    api_key=os.getenv('PINECONE_API_KEY'),  
    environment=os.getenv('PINECONE_ENV')  
)

# %%
if PINECONE_INDEX_NAME not in pinecone.list_indexes():
    pinecone.create_index(
        PINECONE_INDEX_NAME,
        dimension=1536,
        metric='cosine'
    )
    # wait for index to finish initialization
    while not pinecone.describe_index(PINECONE_INDEX_NAME).status['ready']:
        time.sleep(1)

index = pinecone.Index(PINECONE_INDEX_NAME)

# %%
index_name = "langchain-index"

embeddings = OpenAIEmbeddings(deployment="text-embedding-ada-002") #EXPENSIVE - - - USE CAREFULLY

# %%
text_field = "text"  # the metadata field that contains our text

# Initialize the vector store object
vectorstore = Pinecone(
    index, embeddings.embed_query, text_field
)
# Out:
# C:\Users\Uday Ganti\anaconda3\lib\site-packages\langchain\vectorstores\pinecone.py:59: UserWarning: Passing in `embedding` as a Callable is deprecated. Please pass in an Embeddings object instead.
#   warnings.warn(

# %%
class Document:
    def __init__(self, page_content, metadata):
        self.page_content = page_content
        self.metadata = metadata

    def __repr__(self):
        return f"Document(page_content='{self.page_content}', metadata={self.metadata})"


# Define a simple text splitting function
def split_text(text, chunk_size=1000):
    chunks = []
    for i in range(0, len(text), chunk_size):
        chunk = text[i:i+chunk_size]
        chunks.append(chunk)
    return chunks

# %%
text_folder_path = "./Data/Adding"

txt_files = [f for f in os.listdir(text_folder_path) if f.endswith('.txt')]

# Read the contents of each file and store in a list
documents_list = []
for file in txt_files:
    with open(os.path.join(text_folder_path, file), 'r', encoding='utf-8') as f:
        content = f.read()
        documents_list.append(Document(page_content=content, metadata={'text': content}))

# %%
# Instantiate RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)

# Assuming the 'texts' list from previous code
documents_list = [Document(page_content=text, metadata={'text': text}) for text in txt_files]

# %%
print(f"Total number of Documents is: {len(documents_list)}")

for i in range(len(documents_list)):
    try:
        document = documents_list[i]
        print(f"Processing document {i + 1}")

        # Split the document into chunks using the split_text function
        chunks = split_text(document.page_content)

        for chunk in chunks:
            chunk_document = Document(page_content=chunk, metadata={'text': chunk})
            # Vectorize the chunk using Pinecone
            search = Pinecone.from_documents([chunk_document], embeddings, index_name=index_name)

    except Exception as e:
        print(f"Error processing document {i + 1}: {e}")
# Out:
# Total number of Documents is: 14
# Processing document 1
# Processing document 2
# Processing document 3
# Processing document 4
# Processing document 5
# Processing document 6
# Processing document 7
# Processing document 8
# Processing document 9
# Processing document 10
# Processing document 11
# Processing document 12
# Processing document 13
# Processing document 14
